# %%
import pandas as pd
import embedding

# %% [markdown]
# 一旦主語はIだけでやる

# %%
df = pd.read_csv("protocol_example.csv")
df
# Out:
#                                      ESTIMATE  \
# 0               I think [AGENT] is the [ROLE]
# 1      I'm pretty sure [AGENT] is the [ROLE].
# 2                 [AGENT] must be the [ROLE].
# 3              [AGENT] seems like the [ROLE].
# 4            I suspect [AGENT] is the [ROLE].
# 5        I'm convinced [AGENT] is the [ROLE].
# 6            I believe [AGENT] is the [ROLE].
# 7   [AGENT]'s behavior looks like the [ROLE].
# 8        Anya, I think [AGENT] is the [ROLE].
# 9           [AGENT] is definitely the [ROLE].
# 10             I guess [AGENT] is the [ROLE].
# 11             Possibly  [AGENT] is a [ROLE].
#
#                                          CO  \
# 0                    My role is the [ROLE].
# 1                 Actually, I'm the [ROLE].
# 2      I'm assigned the role of the [ROLE].
# 3              I'm the [ROLE] in this game.
# 4                  I'm actually the [ROLE].
# 5       I was given the position of [ROLE].
# 6                      I'm a normal [ROLE].
# 7      I have gained the ability of [ROLE].
# 8                       I am just a [ROLE].
# 9   To tell you the truth, I am the [ROLE].
# 10                                      NaN
# 11                                      NaN
#
#                                               SUSPECT  \
# 0                     [AGENT] is acting really shady.
# 1          [AGENT] has been behaving quite strangely.
# 2   There's something off about the way [AGENT] is...
# 3   I can't help but feel there's something fishy ...
# 4   [AGENT]'s behavior is definitely out of the or...
# 5   [AGENT]'s recent behavior is highly questionable.
# 6                          [AGENT] cannot be trusted.
# 7                    What [AGENT] said is suspicious.
# 8                      Is [AGENT] really trustworthy?
# 9                       [AGENT]'s opinion is dubious.
# 10           I guess the questionable one is [AGENT].
# 11                                                NaN
#
#                                       VOTE  \
# 0            I choose [AGENT] for my vote.
# 1                    [AGENT] gets my vote.
# 2                 My vote goes to [AGENT].
# 3   I believe [AGENT] should be voted out.
# 4                    My choice is [AGENT].
# 5                     I will vote [AGENT].
# 6                  I want to vote [AGENT].
# 7                [AGENT] should be exiled.
# 8                  I would put in [AGENT].
# 9                    I would vote [AGENT].
# 10           Planning to vote for [AGENT].
# 11                                     NaN
#
#                                       DIVINATION  \
# 0           I would like to investigate [AGENT].
# 1      My next target for divination is [AGENT].
# 2           [AGENT] is my choice for divination.
# 3                    I intend to divine [AGENT].
# 4   I'm going to focus my divination on [AGENT].
# 5           I'm going to divine [AGENT] tonight.
# 6                    I will divine [AGENT] next.
# 7        I can tell the [AGENT]'s role tomorrow.
# 8           I will unmask [AGENT]'s true nature.
# 9                                            NaN
# 10             I might investigate [AGENT] next.
# 11                                           NaN
#
#                                               DIVINED  \
# 0   I investigated [AGENT] and discovered he is a ...
# 1   When I looked into [AGENT], it was revealed th...
# 2    My divination revealed that [AGENT] is a [TEAM].
# 3   After performing a divination on [AGENT], it w...
# 4   I divined [AGENT] and the results showed he is...
# 5        Anya divined [AGENT], and he was the [TEAM]!
# 6   I divined [AGENT]. What he said was true, he i...
# 7         According to my ability, [AGENT] is [TEAM].
# 8                 The God says [AGENT] is the [TEAM].
# 9         I revealed [AGENT]'s true nature is [TEAM].
# 10                                                NaN
# 11                                                NaN
#
#                                               AGREE  \
# 0                  I’m on the same page as [AGENT].
# 1                    I’m in agreement with [AGENT].
# 2                    I support [AGENT]'s viewpoint.
# 3                         I back [AGENT]'s opinion.
# 4               I align with [AGENT]'s perspective.
# 5                     Agree with [AGENT]'s opinion.
# 6   I strongly agree with the [AGENT]'s suggestion.
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
#
#                                          NOT ESTIMATE  \
# 0                   I think [AGENT] is not the [ROLE]
# 1           I'm pretty sure [AGENT] isn't the [ROLE].
# 2                     [AGENT] must not be the [ROLE].
# 3               [AGENT] doesn't seem like the [ROLE].
# 4                 I suspect [AGENT] isn't the [ROLE].
# 5            I'm convinced [AGENT] is not the [ROLE].
# 6              I don't believe [AGENT] is the [ROLE].
# 7   [AGENT]'s behavior doesn't looks like the [ROLE].
# 8            Anya, I think [AGENT] is not the [ROLE].
# 9               [AGENT] is not definitely the [ROLE].
# 10               I don't guess [AGENT] is the [ROLE].
# 11                                                NaN
#
#                                 NOT SUSPECT  \
# 0        [AGENT] appears to be trustworthy.
# 1   I don't find [AGENT] suspicious at all.
# 2       There's no reason to doubt [AGENT].
# 3       I have no suspicions about [AGENT].
# 4      I see no signs of deceit in [AGENT].
# 5                   [AGENT] can be trusted.
# 6      What [AGENT] said is not suspicious.
# 7            [AGENT] is really trustworthy.
# 8         [AGENT]'s opinion is not dubious.
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
#
#                                      NOT VOTE  \
# 0         I don't choose [AGENT] for my vote.
# 1                [AGENT] doesn't get my vote.
# 2                My vote won't go to [AGENT].
# 3   I believe [AGENT] shouldn't be voted out.
# 4                   My choice is not [AGENT].
# 5                       I won't vote [AGENT].
# 6                     I want to vote [AGENT].
# 7                   [AGENT] should be exiled.
# 8                     I would put in [AGENT].
# 9                       I would vote [AGENT].
# 10                                        NaN
# 11                                        NaN
#
#                                     NOT AGREE
# 0        I’m not on the same page as [AGENT].
# 1          I’m not in agreement with [AGENT].
# 2        I don't support [AGENT]'s viewpoint.
# 3             I don't back [AGENT]'s opinion.
# 4   I don't align with [AGENT]'s perspective.
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN

# %% [markdown]
# # 全てをembedding

# %%
Agents = ["Agent[00]", "Agent[01]", "Agent[02]", "Agent[03]", "Agent[04]"]
Roles = ["VILLAGER", "SEER", "MEDIUM", "BODYGUARD", "WEREWOLF", "POSSESSED"]
Teams = ["BLACK", "WHITE"]

datalist = {}
for column in df.columns: # 
    ans = [] # あるカラムのすべての要素
    sentences = df[column].dropna().values # .dropna()でnp.nanは落とす
    for sentence in sentences:
        if "[AGENT]" in sentence and "[ROLE]" in sentence:
            for x in Agents:
                for y in Roles:
                    ans.append(sentence.replace('[AGENT]', x).replace('[ROLE]', y))
        elif "[AGENT]" in sentence and "[TEAM]" in sentence:
            for x in Agents:
                for y in Teams:
                    ans.append(sentence.replace('[AGENT]', x).replace('[ROLE]', y))
        elif "[AGENT]" in sentence:
            for x in Agents:
                ans.append(sentence.replace('[AGENT]', x).replace('[ROLE]', y))
        elif '[ROLE]' in sentence:
            for y in Roles:
                    ans.append(sentence.replace('[AGENT]', x).replace('[ROLE]', y))

    datalist[column] = ans

# %%
datalist
# Out:
# {'ESTIMATE': ['I think Agent[00] is the VILLAGER',
#   'I think Agent[00] is the SEER',
#   'I think Agent[00] is the MEDIUM',
#   'I think Agent[00] is the BODYGUARD',
#   'I think Agent[00] is the WEREWOLF',
#   'I think Agent[00] is the POSSESSED',
#   'I think Agent[01] is the VILLAGER',
#   'I think Agent[01] is the SEER',
#   'I think Agent[01] is the MEDIUM',
#   'I think Agent[01] is the BODYGUARD',
#   'I think Agent[01] is the WEREWOLF',
#   'I think Agent[01] is the POSSESSED',
#   'I think Agent[02] is the VILLAGER',
#   'I think Agent[02] is the SEER',
#   'I think Agent[02] is the MEDIUM',
#   'I think Agent[02] is the BODYGUARD',
#   'I think Agent[02] is the WEREWOLF',
#   'I think Agent[02] is the POSSESSED',
#   'I think Agent[03] is the VILLAGER',
#   'I think Agent[03] is the SEER',
#   'I think Agent[03] is the MEDIUM',
#   'I think Agent[03] is the BODYGUARD',
#   'I think Agent[03] is the WEREWOLF',
#   'I think Agent[03] is the POSSESSED',
#   'I think Agent[04] is the VILLAGER',
#   'I think Agent[04] is the SEER',
#   'I think Agent[04] is the MEDIUM',
#   'I think Agent[04] is the BODYGUARD',
#   'I think Agent[04] is the WEREWOLF',
#   'I think Agent[04] is the POSSESSED',
#   "I'm pretty sure Agent[00] is the VILLAGER.",
#   "I'm pretty sure Agent[00] is the SEER.",
#   "I'm pretty sure Agent[00] is the MEDIUM.",
#   "I'm pretty sure Agent[00] is the BODYGUARD.",
#   "I'm pretty sure Agent[00] is the WEREWOLF.",
#   "I'm pretty sure Agent[00] is the POSSESSED.",
#   "I'm pretty sure Agent[01] is the VILLAGER.",
#   "I'm pretty sure Agent[01] is the SEER.",
#   "I'm pretty sure Agent[01] is the MEDIUM.",
#   "I'm pretty sure Agent[01] is the BODYGUARD.",
#   "I'm pretty sure Agent[01] is the WEREWOLF.",
#   "I'm pretty sure Agent[01] is the POSSESSED.",
#   "I'm pretty sure Agent[02] is the VILLAGER.",
#   "I'm pretty sure Agent[02] is the SEER.",
#   "I'm pretty sure Agent[02] is the MEDIUM.",
#   "I'm pretty sure Agent[02] is the BODYGUARD.",
#   "I'm pretty sure Agent[02] is the WEREWOLF.",
#   "I'm pretty sure Agent[02] is the POSSESSED.",
#   "I'm pretty sure Agent[03] is the VILLAGER.",
#   "I'm pretty sure Agent[03] is the SEER.",
#   "I'm pretty sure Agent[03] is the MEDIUM.",
#   "I'm pretty sure Agent[03] is the BODYGUARD.",
#   "I'm pretty sure Agent[03] is the WEREWOLF.",
#   "I'm pretty sure Agent[03] is the POSSESSED.",
#   "I'm pretty sure Agent[04] is the VILLAGER.",
#   "I'm pretty sure Agent[04] is the SEER.",
#   "I'm pretty sure Agent[04] is the MEDIUM.",
#   "I'm pretty sure Agent[04] is the BODYGUARD.",
#   "I'm pretty sure Agent[04] is the WEREWOLF.",
#   "I'm pretty sure Agent[04] is the POSSESSED.",
#   'Agent[00] must be the VILLAGER.',
#   'Agent[00] must be the SEER.',
#   'Agent[00] must be the MEDIUM.',
#   'Agent[00] must be the BODYGUARD.',
#   'Agent[00] must be the WEREWOLF.',
#   'Agent[00] must be the POSSESSED.',
#   'Agent[01] must be the VILLAGER.',
#   'Agent[01] must be the SEER.',
#   'Agent[01] must be the MEDIUM.',
#   'Agent[01] must be the BODYGUARD.',
#   'Agent[01] must be the WEREWOLF.',
#   'Agent[01] must be the POSSESSED.',
#   'Agent[02] must be the VILLAGER.',
#   'Agent[02] must be the SEER.',
#   'Agent[02] must be the MEDIUM.',
#   'Agent[02] must be the BODYGUARD.',
#   'Agent[02] must be the WEREWOLF.',
#   'Agent[02] must be the POSSESSED.',
#   'Agent[03] must be the VILLAGER.',
#   'Agent[03] must be the SEER.',
#   'Agent[03] must be the MEDIUM.',
#   'Agent[03] must be the BODYGUARD.',
#   'Agent[03] must be the WEREWOLF.',
#   'Agent[03] must be the POSSESSED.',
#   'Agent[04] must be the VILLAGER.',
#   'Agent[04] must be the SEER.',
#   'Agent[04] must be the MEDIUM.',
#   'Agent[04] must be the BODYGUARD.',
#   'Agent[04] must be the WEREWOLF.',
#   'Agent[04] must be the POSSESSED.',
#   'Agent[00] seems like the VILLAGER.',
#   'Agent[00] seems like the SEER.',
#   'Agent[00] seems like the MEDIUM.',
#   'Agent[00] seems like the BODYGUARD.',
#   'Agent[00] seems like the WEREWOLF.',
#   'Agent[00] seems like the POSSESSED.',
#   'Agent[01] seems like the VILLAGER.',
#   'Agent[01] seems like the SEER.',
#   'Agent[01] seems like the MEDIUM.',
#   'Agent[01] seems like the BODYGUARD.',
#   'Agent[01] seems like the WEREWOLF.',
#   'Agent[01] seems like the POSSESSED.',
#   'Agent[02] seems like the VILLAGER.',
#   'Agent[02] seems like the SEER.',
#   'Agent[02] seems like the MEDIUM.',
#   'Agent[02] seems like the BODYGUARD.',
#   'Agent[02] seems like the WEREWOLF.',
#   'Agent[02] seems like the POSSESSED.',
#   'Agent[03] seems like the VILLAGER.',
#   'Agent[03] seems like the SEER.',
#   'Agent[03] seems like the MEDIUM.',
#   'Agent[03] seems like the BODYGUARD.',
#   'Agent[03] seems like the WEREWOLF.',
#   'Agent[03] seems like the POSSESSED.',
#   'Agent[04] seems like the VILLAGER.',
#   'Agent[04] seems like the SEER.',
#   'Agent[04] seems like the MEDIUM.',
#   'Agent[04] seems like the BODYGUARD.',
#   'Agent[04] seems like the WEREWOLF.',
#   'Agent[04] seems like the POSSESSED.',
#   'I suspect Agent[00] is the VILLAGER.',
#   'I suspect Agent[00] is the SEER.',
#   'I suspect Agent[00] is the MEDIUM.',
#   'I suspect Agent[00] is the BODYGUARD.',
#   'I suspect Agent[00] is the WEREWOLF.',
#   'I suspect Agent[00] is the POSSESSED.',
#   'I suspect Agent[01] is the VILLAGER.',
#   'I suspect Agent[01] is the SEER.',
#   'I suspect Agent[01] is the MEDIUM.',
#   'I suspect Agent[01] is the BODYGUARD.',
#   'I suspect Agent[01] is the WEREWOLF.',
#   'I suspect Agent[01] is the POSSESSED.',
#   'I suspect Agent[02] is the VILLAGER.',
#   'I suspect Agent[02] is the SEER.',
#   'I suspect Agent[02] is the MEDIUM.',
#   'I suspect Agent[02] is the BODYGUARD.',
#   'I suspect Agent[02] is the WEREWOLF.',
#   'I suspect Agent[02] is the POSSESSED.',
#   'I suspect Agent[03] is the VILLAGER.',
#   'I suspect Agent[03] is the SEER.',
#   'I suspect Agent[03] is the MEDIUM.',
#   'I suspect Agent[03] is the BODYGUARD.',
#   'I suspect Agent[03] is the WEREWOLF.',
#   'I suspect Agent[03] is the POSSESSED.',
#   'I suspect Agent[04] is the VILLAGER.',
#   'I suspect Agent[04] is the SEER.',
#   'I suspect Agent[04] is the MEDIUM.',
#   'I suspect Agent[04] is the BODYGUARD.',
#   'I suspect Agent[04] is the WEREWOLF.',
#   'I suspect Agent[04] is the POSSESSED.',
#   "I'm convinced Agent[00] is the VILLAGER.",
#   "I'm convinced Agent[00] is the SEER.",
#   "I'm convinced Agent[00] is the MEDIUM.",
#   "I'm convinced Agent[00] is the BODYGUARD.",
#   "I'm convinced Agent[00] is the WEREWOLF.",
#   "I'm convinced Agent[00] is the POSSESSED.",
#   "I'm convinced Agent[01] is the VILLAGER.",
#   "I'm convinced Agent[01] is the SEER.",
#   "I'm convinced Agent[01] is the MEDIUM.",
#   "I'm convinced Agent[01] is the BODYGUARD.",
#   "I'm convinced Agent[01] is the WEREWOLF.",
#   "I'm convinced Agent[01] is the POSSESSED.",
#   "I'm convinced Agent[02] is the VILLAGER.",
#   "I'm convinced Agent[02] is the SEER.",
#   "I'm convinced Agent[02] is the MEDIUM.",
#   "I'm convinced Agent[02] is the BODYGUARD.",
#   "I'm convinced Agent[02] is the WEREWOLF.",
#   "I'm convinced Agent[02] is the POSSESSED.",
#   "I'm convinced Agent[03] is the VILLAGER.",
#   "I'm convinced Agent[03] is the SEER.",
#   "I'm convinced Agent[03] is the MEDIUM.",
#   "I'm convinced Agent[03] is the BODYGUARD.",
#   "I'm convinced Agent[03] is the WEREWOLF.",
#   "I'm convinced Agent[03] is the POSSESSED.",
#   "I'm convinced Agent[04] is the VILLAGER.",
#   "I'm convinced Agent[04] is the SEER.",
#   "I'm convinced Agent[04] is the MEDIUM.",
#   "I'm convinced Agent[04] is the BODYGUARD.",
#   "I'm convinced Agent[04] is the WEREWOLF.",
#   "I'm convinced Agent[04] is the POSSESSED.",
#   'I believe Agent[00] is the VILLAGER.',
#   'I believe Agent[00] is the SEER.',
#   'I believe Agent[00] is the MEDIUM.',
#   'I believe Agent[00] is the BODYGUARD.',
#   'I believe Agent[00] is the WEREWOLF.',
#   'I believe Agent[00] is the POSSESSED.',
#   'I believe Agent[01] is the VILLAGER.',
#   'I believe Agent[01] is the SEER.',
#   'I believe Agent[01] is the MEDIUM.',
#   'I believe Agent[01] is the BODYGUARD.',
#   'I believe Agent[01] is the WEREWOLF.',
#   'I believe Agent[01] is the POSSESSED.',
#   'I believe Agent[02] is the VILLAGER.',
#   'I believe Agent[02] is the SEER.',
#   'I believe Agent[02] is the MEDIUM.',
#   'I believe Agent[02] is the BODYGUARD.',
#   'I believe Agent[02] is the WEREWOLF.',
#   'I believe Agent[02] is the POSSESSED.',
#   'I believe Agent[03] is the VILLAGER.',
#   'I believe Agent[03] is the SEER.',
#   'I believe Agent[03] is the MEDIUM.',
#   'I believe Agent[03] is the BODYGUARD.',
#   'I believe Agent[03] is the WEREWOLF.',
#   'I believe Agent[03] is the POSSESSED.',
#   'I believe Agent[04] is the VILLAGER.',
#   'I believe Agent[04] is the SEER.',
#   'I believe Agent[04] is the MEDIUM.',
#   'I believe Agent[04] is the BODYGUARD.',
#   'I believe Agent[04] is the WEREWOLF.',
#   'I believe Agent[04] is the POSSESSED.',
#   "Agent[00]'s behavior looks like the VILLAGER.",
#   "Agent[00]'s behavior looks like the SEER.",
#   "Agent[00]'s behavior looks like the MEDIUM.",
#   "Agent[00]'s behavior looks like the BODYGUARD.",
#   "Agent[00]'s behavior looks like the WEREWOLF.",
#   "Agent[00]'s behavior looks like the POSSESSED.",
#   "Agent[01]'s behavior looks like the VILLAGER.",
#   "Agent[01]'s behavior looks like the SEER.",
#   "Agent[01]'s behavior looks like the MEDIUM.",
#   "Agent[01]'s behavior looks like the BODYGUARD.",
#   "Agent[01]'s behavior looks like the WEREWOLF.",
#   "Agent[01]'s behavior looks like the POSSESSED.",
#   "Agent[02]'s behavior looks like the VILLAGER.",
#   "Agent[02]'s behavior looks like the SEER.",
#   "Agent[02]'s behavior looks like the MEDIUM.",
#   "Agent[02]'s behavior looks like the BODYGUARD.",
#   "Agent[02]'s behavior looks like the WEREWOLF.",
#   "Agent[02]'s behavior looks like the POSSESSED.",
#   "Agent[03]'s behavior looks like the VILLAGER.",
#   "Agent[03]'s behavior looks like the SEER.",
#   "Agent[03]'s behavior looks like the MEDIUM.",
#   "Agent[03]'s behavior looks like the BODYGUARD.",
#   "Agent[03]'s behavior looks like the WEREWOLF.",
#   "Agent[03]'s behavior looks like the POSSESSED.",
#   "Agent[04]'s behavior looks like the VILLAGER.",
#   "Agent[04]'s behavior looks like the SEER.",
#   "Agent[04]'s behavior looks like the MEDIUM.",
#   "Agent[04]'s behavior looks like the BODYGUARD.",
#   "Agent[04]'s behavior looks like the WEREWOLF.",
#   "Agent[04]'s behavior looks like the POSSESSED.",
#   'Anya, I think Agent[00] is the VILLAGER.',
#   'Anya, I think Agent[00] is the SEER.',
#   'Anya, I think Agent[00] is the MEDIUM.',
#   'Anya, I think Agent[00] is the BODYGUARD.',
#   'Anya, I think Agent[00] is the WEREWOLF.',
#   'Anya, I think Agent[00] is the POSSESSED.',
#   'Anya, I think Agent[01] is the VILLAGER.',
#   'Anya, I think Agent[01] is the SEER.',
#   'Anya, I think Agent[01] is the MEDIUM.',
#   'Anya, I think Agent[01] is the BODYGUARD.',
#   'Anya, I think Agent[01] is the WEREWOLF.',
#   'Anya, I think Agent[01] is the POSSESSED.',
#   'Anya, I think Agent[02] is the VILLAGER.',
#   'Anya, I think Agent[02] is the SEER.',
#   'Anya, I think Agent[02] is the MEDIUM.',
#   'Anya, I think Agent[02] is the BODYGUARD.',
#   'Anya, I think Agent[02] is the WEREWOLF.',
#   'Anya, I think Agent[02] is the POSSESSED.',
#   'Anya, I think Agent[03] is the VILLAGER.',
#   'Anya, I think Agent[03] is the SEER.',
#   'Anya, I think Agent[03] is the MEDIUM.',
#   'Anya, I think Agent[03] is the BODYGUARD.',
#   'Anya, I think Agent[03] is the WEREWOLF.',
#   'Anya, I think Agent[03] is the POSSESSED.',
#   'Anya, I think Agent[04] is the VILLAGER.',
#   'Anya, I think Agent[04] is the SEER.',
#   'Anya, I think Agent[04] is the MEDIUM.',
#   'Anya, I think Agent[04] is the BODYGUARD.',
#   'Anya, I think Agent[04] is the WEREWOLF.',
#   'Anya, I think Agent[04] is the POSSESSED.',
#   'Agent[00] is definitely the VILLAGER.',
#   'Agent[00] is definitely the SEER.',
#   'Agent[00] is definitely the MEDIUM.',
#   'Agent[00] is definitely the BODYGUARD.',
#   'Agent[00] is definitely the WEREWOLF.',
#   'Agent[00] is definitely the POSSESSED.',
#   'Agent[01] is definitely the VILLAGER.',
#   'Agent[01] is definitely the SEER.',
#   'Agent[01] is definitely the MEDIUM.',
#   'Agent[01] is definitely the BODYGUARD.',
#   'Agent[01] is definitely the WEREWOLF.',
#   'Agent[01] is definitely the POSSESSED.',
#   'Agent[02] is definitely the VILLAGER.',
#   'Agent[02] is definitely the SEER.',
#   'Agent[02] is definitely the MEDIUM.',
#   'Agent[02] is definitely the BODYGUARD.',
#   'Agent[02] is definitely the WEREWOLF.',
#   'Agent[02] is definitely the POSSESSED.',
#   'Agent[03] is definitely the VILLAGER.',
#   'Agent[03] is definitely the SEER.',
#   'Agent[03] is definitely the MEDIUM.',
#   'Agent[03] is definitely the BODYGUARD.',
#   'Agent[03] is definitely the WEREWOLF.',
#   'Agent[03] is definitely the POSSESSED.',
#   'Agent[04] is definitely the VILLAGER.',
#   'Agent[04] is definitely the SEER.',
#   'Agent[04] is definitely the MEDIUM.',
#   'Agent[04] is definitely the BODYGUARD.',
#   'Agent[04] is definitely the WEREWOLF.',
#   'Agent[04] is definitely the POSSESSED.',
#   'I guess Agent[00] is the VILLAGER.',
#   'I guess Agent[00] is the SEER.',
#   'I guess Agent[00] is the MEDIUM.',
#   'I guess Agent[00] is the BODYGUARD.',
#   'I guess Agent[00] is the WEREWOLF.',
#   'I guess Agent[00] is the POSSESSED.',
#   'I guess Agent[01] is the VILLAGER.',
#   'I guess Agent[01] is the SEER.',
#   'I guess Agent[01] is the MEDIUM.',
#   'I guess Agent[01] is the BODYGUARD.',
#   'I guess Agent[01] is the WEREWOLF.',
#   'I guess Agent[01] is the POSSESSED.',
#   'I guess Agent[02] is the VILLAGER.',
#   'I guess Agent[02] is the SEER.',
#   'I guess Agent[02] is the MEDIUM.',
#   'I guess Agent[02] is the BODYGUARD.',
#   'I guess Agent[02] is the WEREWOLF.',
#   'I guess Agent[02] is the POSSESSED.',
#   'I guess Agent[03] is the VILLAGER.',
#   'I guess Agent[03] is the SEER.',
#   'I guess Agent[03] is the MEDIUM.',
#   'I guess Agent[03] is the BODYGUARD.',
#   'I guess Agent[03] is the WEREWOLF.',
#   'I guess Agent[03] is the POSSESSED.',
#   'I guess Agent[04] is the VILLAGER.',
#   'I guess Agent[04] is the SEER.',
#   'I guess Agent[04] is the MEDIUM.',
#   'I guess Agent[04] is the BODYGUARD.',
#   'I guess Agent[04] is the WEREWOLF.',
#   'I guess Agent[04] is the POSSESSED.',
#   'Possibly  Agent[00] is a VILLAGER.',
#   'Possibly  Agent[00] is a SEER.',
#   'Possibly  Agent[00] is a MEDIUM.',
#   'Possibly  Agent[00] is a BODYGUARD.',
#   'Possibly  Agent[00] is a WEREWOLF.',
#   'Possibly  Agent[00] is a POSSESSED.',
#   'Possibly  Agent[01] is a VILLAGER.',
#   'Possibly  Agent[01] is a SEER.',
#   'Possibly  Agent[01] is a MEDIUM.',
#   'Possibly  Agent[01] is a BODYGUARD.',
#   'Possibly  Agent[01] is a WEREWOLF.',
#   'Possibly  Agent[01] is a POSSESSED.',
#   'Possibly  Agent[02] is a VILLAGER.',
#   'Possibly  Agent[02] is a SEER.',
#   'Possibly  Agent[02] is a MEDIUM.',
#   'Possibly  Agent[02] is a BODYGUARD.',
#   'Possibly  Agent[02] is a WEREWOLF.',
#   'Possibly  Agent[02] is a POSSESSED.',
#   'Possibly  Agent[03] is a VILLAGER.',
#   'Possibly  Agent[03] is a SEER.',
#   'Possibly  Agent[03] is a MEDIUM.',
#   'Possibly  Agent[03] is a BODYGUARD.',
#   'Possibly  Agent[03] is a WEREWOLF.',
#   'Possibly  Agent[03] is a POSSESSED.',
#   'Possibly  Agent[04] is a VILLAGER.',
#   'Possibly  Agent[04] is a SEER.',
#   'Possibly  Agent[04] is a MEDIUM.',
#   'Possibly  Agent[04] is a BODYGUARD.',
#   'Possibly  Agent[04] is a WEREWOLF.',
#   'Possibly  Agent[04] is a POSSESSED.'],
#  'CO': ['My role is the VILLAGER.',
#   'My role is the SEER.',
#   'My role is the MEDIUM.',
#   'My role is the BODYGUARD.',
#   'My role is the WEREWOLF.',
#   'My role is the POSSESSED.',
#   "Actually, I'm the VILLAGER.",
#   "Actually, I'm the SEER.",
#   "Actually, I'm the MEDIUM.",
#   "Actually, I'm the BODYGUARD.",
#   "Actually, I'm the WEREWOLF.",
#   "Actually, I'm the POSSESSED.",
#   "I'm assigned the role of the VILLAGER.",
#   "I'm assigned the role of the SEER.",
#   "I'm assigned the role of the MEDIUM.",
#   "I'm assigned the role of the BODYGUARD.",
#   "I'm assigned the role of the WEREWOLF.",
#   "I'm assigned the role of the POSSESSED.",
#   "I'm the VILLAGER in this game.",
#   "I'm the SEER in this game.",
#   "I'm the MEDIUM in this game.",
#   "I'm the BODYGUARD in this game.",
#   "I'm the WEREWOLF in this game.",
#   "I'm the POSSESSED in this game.",
#   "I'm actually the VILLAGER.",
#   "I'm actually the SEER.",
#   "I'm actually the MEDIUM.",
#   "I'm actually the BODYGUARD.",
#   "I'm actually the WEREWOLF.",
#   "I'm actually the POSSESSED.",
#   'I was given the position of VILLAGER.',
#   'I was given the position of SEER.',
#   'I was given the position of MEDIUM.',
#   'I was given the position of BODYGUARD.',
#   'I was given the position of WEREWOLF.',
#   'I was given the position of POSSESSED.',
#   "I'm a normal VILLAGER.",
#   "I'm a normal SEER.",
#   "I'm a normal MEDIUM.",
#   "I'm a normal BODYGUARD.",
#   "I'm a normal WEREWOLF.",
#   "I'm a normal POSSESSED.",
#   'I have gained the ability of VILLAGER.',
#   'I have gained the ability of SEER.',
#   'I have gained the ability of MEDIUM.',
#   'I have gained the ability of BODYGUARD.',
#   'I have gained the ability of WEREWOLF.',
#   'I have gained the ability of POSSESSED.',
#   'I am just a VILLAGER.',
#   'I am just a SEER.',
#   'I am just a MEDIUM.',
#   'I am just a BODYGUARD.',
#   'I am just a WEREWOLF.',
#   'I am just a POSSESSED.',
#   'To tell you the truth, I am the VILLAGER.',
#   'To tell you the truth, I am the SEER.',
#   'To tell you the truth, I am the MEDIUM.',
#   'To tell you the truth, I am the BODYGUARD.',
#   'To tell you the truth, I am the WEREWOLF.',
#   'To tell you the truth, I am the POSSESSED.'],
#  'SUSPECT': ['Agent[00] is acting really shady.',
#   'Agent[01] is acting really shady.',
#   'Agent[02] is acting really shady.',
#   'Agent[03] is acting really shady.',
#   'Agent[04] is acting really shady.',
#   'Agent[00] has been behaving quite strangely.',
#   'Agent[01] has been behaving quite strangely.',
#   'Agent[02] has been behaving quite strangely.',
#   'Agent[03] has been behaving quite strangely.',
#   'Agent[04] has been behaving quite strangely.',
#   "There's something off about the way Agent[00] is acting.",
#   "There's something off about the way Agent[01] is acting.",
#   "There's something off about the way Agent[02] is acting.",
#   "There's something off about the way Agent[03] is acting.",
#   "There's something off about the way Agent[04] is acting.",
#   "I can't help but feel there's something fishy about Agent[00].",
#   "I can't help but feel there's something fishy about Agent[01].",
#   "I can't help but feel there's something fishy about Agent[02].",
#   "I can't help but feel there's something fishy about Agent[03].",
#   "I can't help but feel there's something fishy about Agent[04].",
#   "Agent[00]'s behavior is definitely out of the ordinary.",
#   "Agent[01]'s behavior is definitely out of the ordinary.",
#   "Agent[02]'s behavior is definitely out of the ordinary.",
#   "Agent[03]'s behavior is definitely out of the ordinary.",
#   "Agent[04]'s behavior is definitely out of the ordinary.",
#   "Agent[00]'s recent behavior is highly questionable.",
#   "Agent[01]'s recent behavior is highly questionable.",
#   "Agent[02]'s recent behavior is highly questionable.",
#   "Agent[03]'s recent behavior is highly questionable.",
#   "Agent[04]'s recent behavior is highly questionable.",
#   'Agent[00] cannot be trusted.',
#   'Agent[01] cannot be trusted.',
#   'Agent[02] cannot be trusted.',
#   'Agent[03] cannot be trusted.',
#   'Agent[04] cannot be trusted.',
#   'What Agent[00] said is suspicious.',
#   'What Agent[01] said is suspicious.',
#   'What Agent[02] said is suspicious.',
#   'What Agent[03] said is suspicious.',
#   'What Agent[04] said is suspicious.',
#   'Is Agent[00] really trustworthy?',
#   'Is Agent[01] really trustworthy?',
#   'Is Agent[02] really trustworthy?',
#   'Is Agent[03] really trustworthy?',
#   'Is Agent[04] really trustworthy?',
#   "Agent[00]'s opinion is dubious.",
#   "Agent[01]'s opinion is dubious.",
#   "Agent[02]'s opinion is dubious.",
#   "Agent[03]'s opinion is dubious.",
#   "Agent[04]'s opinion is dubious.",
#   'I guess the questionable one is Agent[00].',
#   'I guess the questionable one is Agent[01].',
#   'I guess the questionable one is Agent[02].',
#   'I guess the questionable one is Agent[03].',
#   'I guess the questionable one is Agent[04].'],
#  'VOTE': ['I choose Agent[00] for my vote.',
#   'I choose Agent[01] for my vote.',
#   'I choose Agent[02] for my vote.',
#   'I choose Agent[03] for my vote.',
#   'I choose Agent[04] for my vote.',
#   'Agent[00] gets my vote.',
#   'Agent[01] gets my vote.',
#   'Agent[02] gets my vote.',
#   'Agent[03] gets my vote.',
#   'Agent[04] gets my vote.',
#   'My vote goes to Agent[00].',
#   'My vote goes to Agent[01].',
#   'My vote goes to Agent[02].',
#   'My vote goes to Agent[03].',
#   'My vote goes to Agent[04].',
#   'I believe Agent[00] should be voted out.',
#   'I believe Agent[01] should be voted out.',
#   'I believe Agent[02] should be voted out.',
#   'I believe Agent[03] should be voted out.',
#   'I believe Agent[04] should be voted out.',
#   'My choice is Agent[00].',
#   'My choice is Agent[01].',
#   'My choice is Agent[02].',
#   'My choice is Agent[03].',
#   'My choice is Agent[04].',
#   'I will vote Agent[00].',
#   'I will vote Agent[01].',
#   'I will vote Agent[02].',
#   'I will vote Agent[03].',
#   'I will vote Agent[04].',
#   'I want to vote Agent[00].',
#   'I want to vote Agent[01].',
#   'I want to vote Agent[02].',
#   'I want to vote Agent[03].',
#   'I want to vote Agent[04].',
#   'Agent[00] should be exiled.',
#   'Agent[01] should be exiled.',
#   'Agent[02] should be exiled.',
#   'Agent[03] should be exiled.',
#   'Agent[04] should be exiled.',
#   'I would put in Agent[00].',
#   'I would put in Agent[01].',
#   'I would put in Agent[02].',
#   'I would put in Agent[03].',
#   'I would put in Agent[04].',
#   'I would vote Agent[00].',
#   'I would vote Agent[01].',
#   'I would vote Agent[02].',
#   'I would vote Agent[03].',
#   'I would vote Agent[04].',
#   'Planning to vote for Agent[00].',
#   'Planning to vote for Agent[01].',
#   'Planning to vote for Agent[02].',
#   'Planning to vote for Agent[03].',
#   'Planning to vote for Agent[04].'],
#  'DIVINATION': ['I would like to investigate Agent[00].',
#   'I would like to investigate Agent[01].',
#   'I would like to investigate Agent[02].',
#   'I would like to investigate Agent[03].',
#   'I would like to investigate Agent[04].',
#   'My next target for divination is Agent[00].',
#   'My next target for divination is Agent[01].',
#   'My next target for divination is Agent[02].',
#   'My next target for divination is Agent[03].',
#   'My next target for divination is Agent[04].',
#   'Agent[00] is my choice for divination.',
#   'Agent[01] is my choice for divination.',
#   'Agent[02] is my choice for divination.',
#   'Agent[03] is my choice for divination.',
#   'Agent[04] is my choice for divination.',
#   'I intend to divine Agent[00].',
#   'I intend to divine Agent[01].',
#   'I intend to divine Agent[02].',
#   'I intend to divine Agent[03].',
#   'I intend to divine Agent[04].',
#   "I'm going to focus my divination on Agent[00].",
#   "I'm going to focus my divination on Agent[01].",
#   "I'm going to focus my divination on Agent[02].",
#   "I'm going to focus my divination on Agent[03].",
#   "I'm going to focus my divination on Agent[04].",
#   "I'm going to divine Agent[00] tonight.",
#   "I'm going to divine Agent[01] tonight.",
#   "I'm going to divine Agent[02] tonight.",
#   "I'm going to divine Agent[03] tonight.",
#   "I'm going to divine Agent[04] tonight.",
#   'I will divine Agent[00] next.',
#   'I will divine Agent[01] next.',
#   'I will divine Agent[02] next.',
#   'I will divine Agent[03] next.',
#   'I will divine Agent[04] next.',
#   "I can tell the Agent[00]'s role tomorrow.",
#   "I can tell the Agent[01]'s role tomorrow.",
#   "I can tell the Agent[02]'s role tomorrow.",
#   "I can tell the Agent[03]'s role tomorrow.",
#   "I can tell the Agent[04]'s role tomorrow.",
#   "I will unmask Agent[00]'s true nature.",
#   "I will unmask Agent[01]'s true nature.",
#   "I will unmask Agent[02]'s true nature.",
#   "I will unmask Agent[03]'s true nature.",
#   "I will unmask Agent[04]'s true nature.",
#   'I might investigate Agent[00] next.',
#   'I might investigate Agent[01] next.',
#   'I might investigate Agent[02] next.',
#   'I might investigate Agent[03] next.',
#   'I might investigate Agent[04] next.'],
#  'DIVINED': ['I investigated Agent[00] and discovered he is a [TEAM].',
#   'I investigated Agent[00] and discovered he is a [TEAM].',
#   'I investigated Agent[01] and discovered he is a [TEAM].',
#   'I investigated Agent[01] and discovered he is a [TEAM].',
#   'I investigated Agent[02] and discovered he is a [TEAM].',
#   'I investigated Agent[02] and discovered he is a [TEAM].',
#   'I investigated Agent[03] and discovered he is a [TEAM].',
#   'I investigated Agent[03] and discovered he is a [TEAM].',
#   'I investigated Agent[04] and discovered he is a [TEAM].',
#   'I investigated Agent[04] and discovered he is a [TEAM].',
#   'When I looked into Agent[00], it was revealed that he is [TEAM].',
#   'When I looked into Agent[00], it was revealed that he is [TEAM].',
#   'When I looked into Agent[01], it was revealed that he is [TEAM].',
#   'When I looked into Agent[01], it was revealed that he is [TEAM].',
#   'When I looked into Agent[02], it was revealed that he is [TEAM].',
#   'When I looked into Agent[02], it was revealed that he is [TEAM].',
#   'When I looked into Agent[03], it was revealed that he is [TEAM].',
#   'When I looked into Agent[03], it was revealed that he is [TEAM].',
#   'When I looked into Agent[04], it was revealed that he is [TEAM].',
#   'When I looked into Agent[04], it was revealed that he is [TEAM].',
#   'My divination revealed that Agent[00] is a [TEAM].',
#   'My divination revealed that Agent[00] is a [TEAM].',
#   'My divination revealed that Agent[01] is a [TEAM].',
#   'My divination revealed that Agent[01] is a [TEAM].',
#   'My divination revealed that Agent[02] is a [TEAM].',
#   'My divination revealed that Agent[02] is a [TEAM].',
#   'My divination revealed that Agent[03] is a [TEAM].',
#   'My divination revealed that Agent[03] is a [TEAM].',
#   'My divination revealed that Agent[04] is a [TEAM].',
#   'My divination revealed that Agent[04] is a [TEAM].',
#   'After performing a divination on Agent[00], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[00], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[01], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[01], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[02], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[02], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[03], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[03], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[04], it was clear that he is [TEAM].',
#   'After performing a divination on Agent[04], it was clear that he is [TEAM].',
#   'I divined Agent[00] and the results showed he is a [TEAM].',
#   'I divined Agent[00] and the results showed he is a [TEAM].',
#   'I divined Agent[01] and the results showed he is a [TEAM].',
#   'I divined Agent[01] and the results showed he is a [TEAM].',
#   'I divined Agent[02] and the results showed he is a [TEAM].',
#   'I divined Agent[02] and the results showed he is a [TEAM].',
#   'I divined Agent[03] and the results showed he is a [TEAM].',
#   'I divined Agent[03] and the results showed he is a [TEAM].',
#   'I divined Agent[04] and the results showed he is a [TEAM].',
#   'I divined Agent[04] and the results showed he is a [TEAM].',
#   'Anya divined Agent[00], and he was the [TEAM]!',
#   'Anya divined Agent[00], and he was the [TEAM]!',
#   'Anya divined Agent[01], and he was the [TEAM]!',
#   'Anya divined Agent[01], and he was the [TEAM]!',
#   'Anya divined Agent[02], and he was the [TEAM]!',
#   'Anya divined Agent[02], and he was the [TEAM]!',
#   'Anya divined Agent[03], and he was the [TEAM]!',
#   'Anya divined Agent[03], and he was the [TEAM]!',
#   'Anya divined Agent[04], and he was the [TEAM]!',
#   'Anya divined Agent[04], and he was the [TEAM]!',
#   'I divined Agent[00]. What he said was true, he is the [TEAM].',
#   'I divined Agent[00]. What he said was true, he is the [TEAM].',
#   'I divined Agent[01]. What he said was true, he is the [TEAM].',
#   'I divined Agent[01]. What he said was true, he is the [TEAM].',
#   'I divined Agent[02]. What he said was true, he is the [TEAM].',
#   'I divined Agent[02]. What he said was true, he is the [TEAM].',
#   'I divined Agent[03]. What he said was true, he is the [TEAM].',
#   'I divined Agent[03]. What he said was true, he is the [TEAM].',
#   'I divined Agent[04]. What he said was true, he is the [TEAM].',
#   'I divined Agent[04]. What he said was true, he is the [TEAM].',
#   'According to my ability, Agent[00] is [TEAM].',
#   'According to my ability, Agent[00] is [TEAM].',
#   'According to my ability, Agent[01] is [TEAM].',
#   'According to my ability, Agent[01] is [TEAM].',
#   'According to my ability, Agent[02] is [TEAM].',
#   'According to my ability, Agent[02] is [TEAM].',
#   'According to my ability, Agent[03] is [TEAM].',
#   'According to my ability, Agent[03] is [TEAM].',
#   'According to my ability, Agent[04] is [TEAM].',
#   'According to my ability, Agent[04] is [TEAM].',
#   'The God says Agent[00] is the [TEAM].',
#   'The God says Agent[00] is the [TEAM].',
#   'The God says Agent[01] is the [TEAM].',
#   'The God says Agent[01] is the [TEAM].',
#   'The God says Agent[02] is the [TEAM].',
#   'The God says Agent[02] is the [TEAM].',
#   'The God says Agent[03] is the [TEAM].',
#   'The God says Agent[03] is the [TEAM].',
#   'The God says Agent[04] is the [TEAM].',
#   'The God says Agent[04] is the [TEAM].',
#   "I revealed Agent[00]'s true nature is [TEAM].",
#   "I revealed Agent[00]'s true nature is [TEAM].",
#   "I revealed Agent[01]'s true nature is [TEAM].",
#   "I revealed Agent[01]'s true nature is [TEAM].",
#   "I revealed Agent[02]'s true nature is [TEAM].",
#   "I revealed Agent[02]'s true nature is [TEAM].",
#   "I revealed Agent[03]'s true nature is [TEAM].",
#   "I revealed Agent[03]'s true nature is [TEAM].",
#   "I revealed Agent[04]'s true nature is [TEAM].",
#   "I revealed Agent[04]'s true nature is [TEAM]."],
#  'AGREE': ['I’m on the same page as Agent[00].',
#   'I’m on the same page as Agent[01].',
#   'I’m on the same page as Agent[02].',
#   'I’m on the same page as Agent[03].',
#   'I’m on the same page as Agent[04].',
#   'I’m in agreement with Agent[00].',
#   'I’m in agreement with Agent[01].',
#   'I’m in agreement with Agent[02].',
#   'I’m in agreement with Agent[03].',
#   'I’m in agreement with Agent[04].',
#   "I support Agent[00]'s viewpoint.",
#   "I support Agent[01]'s viewpoint.",
#   "I support Agent[02]'s viewpoint.",
#   "I support Agent[03]'s viewpoint.",
#   "I support Agent[04]'s viewpoint.",
#   "I back Agent[00]'s opinion.",
#   "I back Agent[01]'s opinion.",
#   "I back Agent[02]'s opinion.",
#   "I back Agent[03]'s opinion.",
#   "I back Agent[04]'s opinion.",
#   "I align with Agent[00]'s perspective.",
#   "I align with Agent[01]'s perspective.",
#   "I align with Agent[02]'s perspective.",
#   "I align with Agent[03]'s perspective.",
#   "I align with Agent[04]'s perspective.",
#   "Agree with Agent[00]'s opinion.",
#   "Agree with Agent[01]'s opinion.",
#   "Agree with Agent[02]'s opinion.",
#   "Agree with Agent[03]'s opinion.",
#   "Agree with Agent[04]'s opinion.",
#   "I strongly agree with the Agent[00]'s suggestion.",
#   "I strongly agree with the Agent[01]'s suggestion.",
#   "I strongly agree with the Agent[02]'s suggestion.",
#   "I strongly agree with the Agent[03]'s suggestion.",
#   "I strongly agree with the Agent[04]'s suggestion."],
#  'NOT ESTIMATE': ['I think Agent[00] is not the VILLAGER',
#   'I think Agent[00] is not the SEER',
#   'I think Agent[00] is not the MEDIUM',
#   'I think Agent[00] is not the BODYGUARD',
#   'I think Agent[00] is not the WEREWOLF',
#   'I think Agent[00] is not the POSSESSED',
#   'I think Agent[01] is not the VILLAGER',
#   'I think Agent[01] is not the SEER',
#   'I think Agent[01] is not the MEDIUM',
#   'I think Agent[01] is not the BODYGUARD',
#   'I think Agent[01] is not the WEREWOLF',
#   'I think Agent[01] is not the POSSESSED',
#   'I think Agent[02] is not the VILLAGER',
#   'I think Agent[02] is not the SEER',
#   'I think Agent[02] is not the MEDIUM',
#   'I think Agent[02] is not the BODYGUARD',
#   'I think Agent[02] is not the WEREWOLF',
#   'I think Agent[02] is not the POSSESSED',
#   'I think Agent[03] is not the VILLAGER',
#   'I think Agent[03] is not the SEER',
#   'I think Agent[03] is not the MEDIUM',
#   'I think Agent[03] is not the BODYGUARD',
#   'I think Agent[03] is not the WEREWOLF',
#   'I think Agent[03] is not the POSSESSED',
#   'I think Agent[04] is not the VILLAGER',
#   'I think Agent[04] is not the SEER',
#   'I think Agent[04] is not the MEDIUM',
#   'I think Agent[04] is not the BODYGUARD',
#   'I think Agent[04] is not the WEREWOLF',
#   'I think Agent[04] is not the POSSESSED',
#   "I'm pretty sure Agent[00] isn't the VILLAGER.",
#   "I'm pretty sure Agent[00] isn't the SEER.",
#   "I'm pretty sure Agent[00] isn't the MEDIUM.",
#   "I'm pretty sure Agent[00] isn't the BODYGUARD.",
#   "I'm pretty sure Agent[00] isn't the WEREWOLF.",
#   "I'm pretty sure Agent[00] isn't the POSSESSED.",
#   "I'm pretty sure Agent[01] isn't the VILLAGER.",
#   "I'm pretty sure Agent[01] isn't the SEER.",
#   "I'm pretty sure Agent[01] isn't the MEDIUM.",
#   "I'm pretty sure Agent[01] isn't the BODYGUARD.",
#   "I'm pretty sure Agent[01] isn't the WEREWOLF.",
#   "I'm pretty sure Agent[01] isn't the POSSESSED.",
#   "I'm pretty sure Agent[02] isn't the VILLAGER.",
#   "I'm pretty sure Agent[02] isn't the SEER.",
#   "I'm pretty sure Agent[02] isn't the MEDIUM.",
#   "I'm pretty sure Agent[02] isn't the BODYGUARD.",
#   "I'm pretty sure Agent[02] isn't the WEREWOLF.",
#   "I'm pretty sure Agent[02] isn't the POSSESSED.",
#   "I'm pretty sure Agent[03] isn't the VILLAGER.",
#   "I'm pretty sure Agent[03] isn't the SEER.",
#   "I'm pretty sure Agent[03] isn't the MEDIUM.",
#   "I'm pretty sure Agent[03] isn't the BODYGUARD.",
#   "I'm pretty sure Agent[03] isn't the WEREWOLF.",
#   "I'm pretty sure Agent[03] isn't the POSSESSED.",
#   "I'm pretty sure Agent[04] isn't the VILLAGER.",
#   "I'm pretty sure Agent[04] isn't the SEER.",
#   "I'm pretty sure Agent[04] isn't the MEDIUM.",
#   "I'm pretty sure Agent[04] isn't the BODYGUARD.",
#   "I'm pretty sure Agent[04] isn't the WEREWOLF.",
#   "I'm pretty sure Agent[04] isn't the POSSESSED.",
#   'Agent[00] must not be the VILLAGER.',
#   'Agent[00] must not be the SEER.',
#   'Agent[00] must not be the MEDIUM.',
#   'Agent[00] must not be the BODYGUARD.',
#   'Agent[00] must not be the WEREWOLF.',
#   'Agent[00] must not be the POSSESSED.',
#   'Agent[01] must not be the VILLAGER.',
#   'Agent[01] must not be the SEER.',
#   'Agent[01] must not be the MEDIUM.',
#   'Agent[01] must not be the BODYGUARD.',
#   'Agent[01] must not be the WEREWOLF.',
#   'Agent[01] must not be the POSSESSED.',
#   'Agent[02] must not be the VILLAGER.',
#   'Agent[02] must not be the SEER.',
#   'Agent[02] must not be the MEDIUM.',
#   'Agent[02] must not be the BODYGUARD.',
#   'Agent[02] must not be the WEREWOLF.',
#   'Agent[02] must not be the POSSESSED.',
#   'Agent[03] must not be the VILLAGER.',
#   'Agent[03] must not be the SEER.',
#   'Agent[03] must not be the MEDIUM.',
#   'Agent[03] must not be the BODYGUARD.',
#   'Agent[03] must not be the WEREWOLF.',
#   'Agent[03] must not be the POSSESSED.',
#   'Agent[04] must not be the VILLAGER.',
#   'Agent[04] must not be the SEER.',
#   'Agent[04] must not be the MEDIUM.',
#   'Agent[04] must not be the BODYGUARD.',
#   'Agent[04] must not be the WEREWOLF.',
#   'Agent[04] must not be the POSSESSED.',
#   "Agent[00] doesn't seem like the VILLAGER.",
#   "Agent[00] doesn't seem like the SEER.",
#   "Agent[00] doesn't seem like the MEDIUM.",
#   "Agent[00] doesn't seem like the BODYGUARD.",
#   "Agent[00] doesn't seem like the WEREWOLF.",
#   "Agent[00] doesn't seem like the POSSESSED.",
#   "Agent[01] doesn't seem like the VILLAGER.",
#   "Agent[01] doesn't seem like the SEER.",
#   "Agent[01] doesn't seem like the MEDIUM.",
#   "Agent[01] doesn't seem like the BODYGUARD.",
#   "Agent[01] doesn't seem like the WEREWOLF.",
#   "Agent[01] doesn't seem like the POSSESSED.",
#   "Agent[02] doesn't seem like the VILLAGER.",
#   "Agent[02] doesn't seem like the SEER.",
#   "Agent[02] doesn't seem like the MEDIUM.",
#   "Agent[02] doesn't seem like the BODYGUARD.",
#   "Agent[02] doesn't seem like the WEREWOLF.",
#   "Agent[02] doesn't seem like the POSSESSED.",
#   "Agent[03] doesn't seem like the VILLAGER.",
#   "Agent[03] doesn't seem like the SEER.",
#   "Agent[03] doesn't seem like the MEDIUM.",
#   "Agent[03] doesn't seem like the BODYGUARD.",
#   "Agent[03] doesn't seem like the WEREWOLF.",
#   "Agent[03] doesn't seem like the POSSESSED.",
#   "Agent[04] doesn't seem like the VILLAGER.",
#   "Agent[04] doesn't seem like the SEER.",
#   "Agent[04] doesn't seem like the MEDIUM.",
#   "Agent[04] doesn't seem like the BODYGUARD.",
#   "Agent[04] doesn't seem like the WEREWOLF.",
#   "Agent[04] doesn't seem like the POSSESSED.",
#   "I suspect Agent[00] isn't the VILLAGER.",
#   "I suspect Agent[00] isn't the SEER.",
#   "I suspect Agent[00] isn't the MEDIUM.",
#   "I suspect Agent[00] isn't the BODYGUARD.",
#   "I suspect Agent[00] isn't the WEREWOLF.",
#   "I suspect Agent[00] isn't the POSSESSED.",
#   "I suspect Agent[01] isn't the VILLAGER.",
#   "I suspect Agent[01] isn't the SEER.",
#   "I suspect Agent[01] isn't the MEDIUM.",
#   "I suspect Agent[01] isn't the BODYGUARD.",
#   "I suspect Agent[01] isn't the WEREWOLF.",
#   "I suspect Agent[01] isn't the POSSESSED.",
#   "I suspect Agent[02] isn't the VILLAGER.",
#   "I suspect Agent[02] isn't the SEER.",
#   "I suspect Agent[02] isn't the MEDIUM.",
#   "I suspect Agent[02] isn't the BODYGUARD.",
#   "I suspect Agent[02] isn't the WEREWOLF.",
#   "I suspect Agent[02] isn't the POSSESSED.",
#   "I suspect Agent[03] isn't the VILLAGER.",
#   "I suspect Agent[03] isn't the SEER.",
#   "I suspect Agent[03] isn't the MEDIUM.",
#   "I suspect Agent[03] isn't the BODYGUARD.",
#   "I suspect Agent[03] isn't the WEREWOLF.",
#   "I suspect Agent[03] isn't the POSSESSED.",
#   "I suspect Agent[04] isn't the VILLAGER.",
#   "I suspect Agent[04] isn't the SEER.",
#   "I suspect Agent[04] isn't the MEDIUM.",
#   "I suspect Agent[04] isn't the BODYGUARD.",
#   "I suspect Agent[04] isn't the WEREWOLF.",
#   "I suspect Agent[04] isn't the POSSESSED.",
#   "I'm convinced Agent[00] is not the VILLAGER.",
#   "I'm convinced Agent[00] is not the SEER.",
#   "I'm convinced Agent[00] is not the MEDIUM.",
#   "I'm convinced Agent[00] is not the BODYGUARD.",
#   "I'm convinced Agent[00] is not the WEREWOLF.",
#   "I'm convinced Agent[00] is not the POSSESSED.",
#   "I'm convinced Agent[01] is not the VILLAGER.",
#   "I'm convinced Agent[01] is not the SEER.",
#   "I'm convinced Agent[01] is not the MEDIUM.",
#   "I'm convinced Agent[01] is not the BODYGUARD.",
#   "I'm convinced Agent[01] is not the WEREWOLF.",
#   "I'm convinced Agent[01] is not the POSSESSED.",
#   "I'm convinced Agent[02] is not the VILLAGER.",
#   "I'm convinced Agent[02] is not the SEER.",
#   "I'm convinced Agent[02] is not the MEDIUM.",
#   "I'm convinced Agent[02] is not the BODYGUARD.",
#   "I'm convinced Agent[02] is not the WEREWOLF.",
#   "I'm convinced Agent[02] is not the POSSESSED.",
#   "I'm convinced Agent[03] is not the VILLAGER.",
#   "I'm convinced Agent[03] is not the SEER.",
#   "I'm convinced Agent[03] is not the MEDIUM.",
#   "I'm convinced Agent[03] is not the BODYGUARD.",
#   "I'm convinced Agent[03] is not the WEREWOLF.",
#   "I'm convinced Agent[03] is not the POSSESSED.",
#   "I'm convinced Agent[04] is not the VILLAGER.",
#   "I'm convinced Agent[04] is not the SEER.",
#   "I'm convinced Agent[04] is not the MEDIUM.",
#   "I'm convinced Agent[04] is not the BODYGUARD.",
#   "I'm convinced Agent[04] is not the WEREWOLF.",
#   "I'm convinced Agent[04] is not the POSSESSED.",
#   "I don't believe Agent[00] is the VILLAGER.",
#   "I don't believe Agent[00] is the SEER.",
#   "I don't believe Agent[00] is the MEDIUM.",
#   "I don't believe Agent[00] is the BODYGUARD.",
#   "I don't believe Agent[00] is the WEREWOLF.",
#   "I don't believe Agent[00] is the POSSESSED.",
#   "I don't believe Agent[01] is the VILLAGER.",
#   "I don't believe Agent[01] is the SEER.",
#   "I don't believe Agent[01] is the MEDIUM.",
#   "I don't believe Agent[01] is the BODYGUARD.",
#   "I don't believe Agent[01] is the WEREWOLF.",
#   "I don't believe Agent[01] is the POSSESSED.",
#   "I don't believe Agent[02] is the VILLAGER.",
#   "I don't believe Agent[02] is the SEER.",
#   "I don't believe Agent[02] is the MEDIUM.",
#   "I don't believe Agent[02] is the BODYGUARD.",
#   "I don't believe Agent[02] is the WEREWOLF.",
#   "I don't believe Agent[02] is the POSSESSED.",
#   "I don't believe Agent[03] is the VILLAGER.",
#   "I don't believe Agent[03] is the SEER.",
#   "I don't believe Agent[03] is the MEDIUM.",
#   "I don't believe Agent[03] is the BODYGUARD.",
#   "I don't believe Agent[03] is the WEREWOLF.",
#   "I don't believe Agent[03] is the POSSESSED.",
#   "I don't believe Agent[04] is the VILLAGER.",
#   "I don't believe Agent[04] is the SEER.",
#   "I don't believe Agent[04] is the MEDIUM.",
#   "I don't believe Agent[04] is the BODYGUARD.",
#   "I don't believe Agent[04] is the WEREWOLF.",
#   "I don't believe Agent[04] is the POSSESSED.",
#   "Agent[00]'s behavior doesn't looks like the VILLAGER.",
#   "Agent[00]'s behavior doesn't looks like the SEER.",
#   "Agent[00]'s behavior doesn't looks like the MEDIUM.",
#   "Agent[00]'s behavior doesn't looks like the BODYGUARD.",
#   "Agent[00]'s behavior doesn't looks like the WEREWOLF.",
#   "Agent[00]'s behavior doesn't looks like the POSSESSED.",
#   "Agent[01]'s behavior doesn't looks like the VILLAGER.",
#   "Agent[01]'s behavior doesn't looks like the SEER.",
#   "Agent[01]'s behavior doesn't looks like the MEDIUM.",
#   "Agent[01]'s behavior doesn't looks like the BODYGUARD.",
#   "Agent[01]'s behavior doesn't looks like the WEREWOLF.",
#   "Agent[01]'s behavior doesn't looks like the POSSESSED.",
#   "Agent[02]'s behavior doesn't looks like the VILLAGER.",
#   "Agent[02]'s behavior doesn't looks like the SEER.",
#   "Agent[02]'s behavior doesn't looks like the MEDIUM.",
#   "Agent[02]'s behavior doesn't looks like the BODYGUARD.",
#   "Agent[02]'s behavior doesn't looks like the WEREWOLF.",
#   "Agent[02]'s behavior doesn't looks like the POSSESSED.",
#   "Agent[03]'s behavior doesn't looks like the VILLAGER.",
#   "Agent[03]'s behavior doesn't looks like the SEER.",
#   "Agent[03]'s behavior doesn't looks like the MEDIUM.",
#   "Agent[03]'s behavior doesn't looks like the BODYGUARD.",
#   "Agent[03]'s behavior doesn't looks like the WEREWOLF.",
#   "Agent[03]'s behavior doesn't looks like the POSSESSED.",
#   "Agent[04]'s behavior doesn't looks like the VILLAGER.",
#   "Agent[04]'s behavior doesn't looks like the SEER.",
#   "Agent[04]'s behavior doesn't looks like the MEDIUM.",
#   "Agent[04]'s behavior doesn't looks like the BODYGUARD.",
#   "Agent[04]'s behavior doesn't looks like the WEREWOLF.",
#   "Agent[04]'s behavior doesn't looks like the POSSESSED.",
#   'Anya, I think Agent[00] is not the VILLAGER.',
#   'Anya, I think Agent[00] is not the SEER.',
#   'Anya, I think Agent[00] is not the MEDIUM.',
#   'Anya, I think Agent[00] is not the BODYGUARD.',
#   'Anya, I think Agent[00] is not the WEREWOLF.',
#   'Anya, I think Agent[00] is not the POSSESSED.',
#   'Anya, I think Agent[01] is not the VILLAGER.',
#   'Anya, I think Agent[01] is not the SEER.',
#   'Anya, I think Agent[01] is not the MEDIUM.',
#   'Anya, I think Agent[01] is not the BODYGUARD.',
#   'Anya, I think Agent[01] is not the WEREWOLF.',
#   'Anya, I think Agent[01] is not the POSSESSED.',
#   'Anya, I think Agent[02] is not the VILLAGER.',
#   'Anya, I think Agent[02] is not the SEER.',
#   'Anya, I think Agent[02] is not the MEDIUM.',
#   'Anya, I think Agent[02] is not the BODYGUARD.',
#   'Anya, I think Agent[02] is not the WEREWOLF.',
#   'Anya, I think Agent[02] is not the POSSESSED.',
#   'Anya, I think Agent[03] is not the VILLAGER.',
#   'Anya, I think Agent[03] is not the SEER.',
#   'Anya, I think Agent[03] is not the MEDIUM.',
#   'Anya, I think Agent[03] is not the BODYGUARD.',
#   'Anya, I think Agent[03] is not the WEREWOLF.',
#   'Anya, I think Agent[03] is not the POSSESSED.',
#   'Anya, I think Agent[04] is not the VILLAGER.',
#   'Anya, I think Agent[04] is not the SEER.',
#   'Anya, I think Agent[04] is not the MEDIUM.',
#   'Anya, I think Agent[04] is not the BODYGUARD.',
#   'Anya, I think Agent[04] is not the WEREWOLF.',
#   'Anya, I think Agent[04] is not the POSSESSED.',
#   'Agent[00] is not definitely the VILLAGER.',
#   'Agent[00] is not definitely the SEER.',
#   'Agent[00] is not definitely the MEDIUM.',
#   'Agent[00] is not definitely the BODYGUARD.',
#   'Agent[00] is not definitely the WEREWOLF.',
#   'Agent[00] is not definitely the POSSESSED.',
#   'Agent[01] is not definitely the VILLAGER.',
#   'Agent[01] is not definitely the SEER.',
#   'Agent[01] is not definitely the MEDIUM.',
#   'Agent[01] is not definitely the BODYGUARD.',
#   'Agent[01] is not definitely the WEREWOLF.',
#   'Agent[01] is not definitely the POSSESSED.',
#   'Agent[02] is not definitely the VILLAGER.',
#   'Agent[02] is not definitely the SEER.',
#   'Agent[02] is not definitely the MEDIUM.',
#   'Agent[02] is not definitely the BODYGUARD.',
#   'Agent[02] is not definitely the WEREWOLF.',
#   'Agent[02] is not definitely the POSSESSED.',
#   'Agent[03] is not definitely the VILLAGER.',
#   'Agent[03] is not definitely the SEER.',
#   'Agent[03] is not definitely the MEDIUM.',
#   'Agent[03] is not definitely the BODYGUARD.',
#   'Agent[03] is not definitely the WEREWOLF.',
#   'Agent[03] is not definitely the POSSESSED.',
#   'Agent[04] is not definitely the VILLAGER.',
#   'Agent[04] is not definitely the SEER.',
#   'Agent[04] is not definitely the MEDIUM.',
#   'Agent[04] is not definitely the BODYGUARD.',
#   'Agent[04] is not definitely the WEREWOLF.',
#   'Agent[04] is not definitely the POSSESSED.',
#   "I don't guess Agent[00] is the VILLAGER.",
#   "I don't guess Agent[00] is the SEER.",
#   "I don't guess Agent[00] is the MEDIUM.",
#   "I don't guess Agent[00] is the BODYGUARD.",
#   "I don't guess Agent[00] is the WEREWOLF.",
#   "I don't guess Agent[00] is the POSSESSED.",
#   "I don't guess Agent[01] is the VILLAGER.",
#   "I don't guess Agent[01] is the SEER.",
#   "I don't guess Agent[01] is the MEDIUM.",
#   "I don't guess Agent[01] is the BODYGUARD.",
#   "I don't guess Agent[01] is the WEREWOLF.",
#   "I don't guess Agent[01] is the POSSESSED.",
#   "I don't guess Agent[02] is the VILLAGER.",
#   "I don't guess Agent[02] is the SEER.",
#   "I don't guess Agent[02] is the MEDIUM.",
#   "I don't guess Agent[02] is the BODYGUARD.",
#   "I don't guess Agent[02] is the WEREWOLF.",
#   "I don't guess Agent[02] is the POSSESSED.",
#   "I don't guess Agent[03] is the VILLAGER.",
#   "I don't guess Agent[03] is the SEER.",
#   "I don't guess Agent[03] is the MEDIUM.",
#   "I don't guess Agent[03] is the BODYGUARD.",
#   "I don't guess Agent[03] is the WEREWOLF.",
#   "I don't guess Agent[03] is the POSSESSED.",
#   "I don't guess Agent[04] is the VILLAGER.",
#   "I don't guess Agent[04] is the SEER.",
#   "I don't guess Agent[04] is the MEDIUM.",
#   "I don't guess Agent[04] is the BODYGUARD.",
#   "I don't guess Agent[04] is the WEREWOLF.",
#   "I don't guess Agent[04] is the POSSESSED."],
#  'NOT SUSPECT': ['Agent[00] appears to be trustworthy.',
#   'Agent[01] appears to be trustworthy.',
#   'Agent[02] appears to be trustworthy.',
#   'Agent[03] appears to be trustworthy.',
#   'Agent[04] appears to be trustworthy.',
#   "I don't find Agent[00] suspicious at all.",
#   "I don't find Agent[01] suspicious at all.",
#   "I don't find Agent[02] suspicious at all.",
#   "I don't find Agent[03] suspicious at all.",
#   "I don't find Agent[04] suspicious at all.",
#   "There's no reason to doubt Agent[00].",
#   "There's no reason to doubt Agent[01].",
#   "There's no reason to doubt Agent[02].",
#   "There's no reason to doubt Agent[03].",
#   "There's no reason to doubt Agent[04].",
#   'I have no suspicions about Agent[00].',
#   'I have no suspicions about Agent[01].',
#   'I have no suspicions about Agent[02].',
#   'I have no suspicions about Agent[03].',
#   'I have no suspicions about Agent[04].',
#   'I see no signs of deceit in Agent[00].',
#   'I see no signs of deceit in Agent[01].',
#   'I see no signs of deceit in Agent[02].',
#   'I see no signs of deceit in Agent[03].',
#   'I see no signs of deceit in Agent[04].',
#   'Agent[00] can be trusted.',
#   'Agent[01] can be trusted.',
#   'Agent[02] can be trusted.',
#   'Agent[03] can be trusted.',
#   'Agent[04] can be trusted.',
#   'What Agent[00] said is not suspicious.',
#   'What Agent[01] said is not suspicious.',
#   'What Agent[02] said is not suspicious.',
#   'What Agent[03] said is not suspicious.',
#   'What Agent[04] said is not suspicious.',
#   'Agent[00] is really trustworthy.',
#   'Agent[01] is really trustworthy.',
#   'Agent[02] is really trustworthy.',
#   'Agent[03] is really trustworthy.',
#   'Agent[04] is really trustworthy.',
#   "Agent[00]'s opinion is not dubious.",
#   "Agent[01]'s opinion is not dubious.",
#   "Agent[02]'s opinion is not dubious.",
#   "Agent[03]'s opinion is not dubious.",
#   "Agent[04]'s opinion is not dubious."],
#  'NOT VOTE': ["I don't choose Agent[00] for my vote.",
#   "I don't choose Agent[01] for my vote.",
#   "I don't choose Agent[02] for my vote.",
#   "I don't choose Agent[03] for my vote.",
#   "I don't choose Agent[04] for my vote.",
#   "Agent[00] doesn't get my vote.",
#   "Agent[01] doesn't get my vote.",
#   "Agent[02] doesn't get my vote.",
#   "Agent[03] doesn't get my vote.",
#   "Agent[04] doesn't get my vote.",
#   "My vote won't go to Agent[00].",
#   "My vote won't go to Agent[01].",
#   "My vote won't go to Agent[02].",
#   "My vote won't go to Agent[03].",
#   "My vote won't go to Agent[04].",
#   "I believe Agent[00] shouldn't be voted out.",
#   "I believe Agent[01] shouldn't be voted out.",
#   "I believe Agent[02] shouldn't be voted out.",
#   "I believe Agent[03] shouldn't be voted out.",
#   "I believe Agent[04] shouldn't be voted out.",
#   'My choice is not Agent[00].',
#   'My choice is not Agent[01].',
#   'My choice is not Agent[02].',
#   'My choice is not Agent[03].',
#   'My choice is not Agent[04].',
#   "I won't vote Agent[00].",
#   "I won't vote Agent[01].",
#   "I won't vote Agent[02].",
#   "I won't vote Agent[03].",
#   "I won't vote Agent[04].",
#   'I want to vote Agent[00].',
#   'I want to vote Agent[01].',
#   'I want to vote Agent[02].',
#   'I want to vote Agent[03].',
#   'I want to vote Agent[04].',
#   'Agent[00] should be exiled.',
#   'Agent[01] should be exiled.',
#   'Agent[02] should be exiled.',
#   'Agent[03] should be exiled.',
#   'Agent[04] should be exiled.',
#   'I would put in Agent[00].',
#   'I would put in Agent[01].',
#   'I would put in Agent[02].',
#   'I would put in Agent[03].',
#   'I would put in Agent[04].',
#   'I would vote Agent[00].',
#   'I would vote Agent[01].',
#   'I would vote Agent[02].',
#   'I would vote Agent[03].',
#   'I would vote Agent[04].'],
#  'NOT AGREE': ['I’m not on the same page as Agent[00].',
#   'I’m not on the same page as Agent[01].',
#   'I’m not on the same page as Agent[02].',
#   'I’m not on the same page as Agent[03].',
#   'I’m not on the same page as Agent[04].',
#   'I’m not in agreement with Agent[00].',
#   'I’m not in agreement with Agent[01].',
#   'I’m not in agreement with Agent[02].',
#   'I’m not in agreement with Agent[03].',
#   'I’m not in agreement with Agent[04].',
#   "I don't support Agent[00]'s viewpoint.",
#   "I don't support Agent[01]'s viewpoint.",
#   "I don't support Agent[02]'s viewpoint.",
#   "I don't support Agent[03]'s viewpoint.",
#   "I don't support Agent[04]'s viewpoint.",
#   "I don't back Agent[00]'s opinion.",
#   "I don't back Agent[01]'s opinion.",
#   "I don't back Agent[02]'s opinion.",
#   "I don't back Agent[03]'s opinion.",
#   "I don't back Agent[04]'s opinion.",
#   "I don't align with Agent[00]'s perspective.",
#   "I don't align with Agent[01]'s perspective.",
#   "I don't align with Agent[02]'s perspective.",
#   "I don't align with Agent[03]'s perspective.",
#   "I don't align with Agent[04]'s perspective."]}

# %%
data = []
for key, val in (datalist.items()):
    for i in val:
        data.append([i, key])

# %%
data
# Out:
# [['I think Agent[00] is the VILLAGER', 'ESTIMATE'],
#  ['I think Agent[00] is the SEER', 'ESTIMATE'],
#  ['I think Agent[00] is the MEDIUM', 'ESTIMATE'],
#  ['I think Agent[00] is the BODYGUARD', 'ESTIMATE'],
#  ['I think Agent[00] is the WEREWOLF', 'ESTIMATE'],
#  ['I think Agent[00] is the POSSESSED', 'ESTIMATE'],
#  ['I think Agent[01] is the VILLAGER', 'ESTIMATE'],
#  ['I think Agent[01] is the SEER', 'ESTIMATE'],
#  ['I think Agent[01] is the MEDIUM', 'ESTIMATE'],
#  ['I think Agent[01] is the BODYGUARD', 'ESTIMATE'],
#  ['I think Agent[01] is the WEREWOLF', 'ESTIMATE'],
#  ['I think Agent[01] is the POSSESSED', 'ESTIMATE'],
#  ['I think Agent[02] is the VILLAGER', 'ESTIMATE'],
#  ['I think Agent[02] is the SEER', 'ESTIMATE'],
#  ['I think Agent[02] is the MEDIUM', 'ESTIMATE'],
#  ['I think Agent[02] is the BODYGUARD', 'ESTIMATE'],
#  ['I think Agent[02] is the WEREWOLF', 'ESTIMATE'],
#  ['I think Agent[02] is the POSSESSED', 'ESTIMATE'],
#  ['I think Agent[03] is the VILLAGER', 'ESTIMATE'],
#  ['I think Agent[03] is the SEER', 'ESTIMATE'],
#  ['I think Agent[03] is the MEDIUM', 'ESTIMATE'],
#  ['I think Agent[03] is the BODYGUARD', 'ESTIMATE'],
#  ['I think Agent[03] is the WEREWOLF', 'ESTIMATE'],
#  ['I think Agent[03] is the POSSESSED', 'ESTIMATE'],
#  ['I think Agent[04] is the VILLAGER', 'ESTIMATE'],
#  ['I think Agent[04] is the SEER', 'ESTIMATE'],
#  ['I think Agent[04] is the MEDIUM', 'ESTIMATE'],
#  ['I think Agent[04] is the BODYGUARD', 'ESTIMATE'],
#  ['I think Agent[04] is the WEREWOLF', 'ESTIMATE'],
#  ['I think Agent[04] is the POSSESSED', 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the SEER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[00] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the SEER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[01] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the SEER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[02] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the SEER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[03] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the SEER.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm pretty sure Agent[04] is the POSSESSED.", 'ESTIMATE'],
#  ['Agent[00] must be the VILLAGER.', 'ESTIMATE'],
#  ['Agent[00] must be the SEER.', 'ESTIMATE'],
#  ['Agent[00] must be the MEDIUM.', 'ESTIMATE'],
#  ['Agent[00] must be the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[00] must be the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[00] must be the POSSESSED.', 'ESTIMATE'],
#  ['Agent[01] must be the VILLAGER.', 'ESTIMATE'],
#  ['Agent[01] must be the SEER.', 'ESTIMATE'],
#  ['Agent[01] must be the MEDIUM.', 'ESTIMATE'],
#  ['Agent[01] must be the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[01] must be the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[01] must be the POSSESSED.', 'ESTIMATE'],
#  ['Agent[02] must be the VILLAGER.', 'ESTIMATE'],
#  ['Agent[02] must be the SEER.', 'ESTIMATE'],
#  ['Agent[02] must be the MEDIUM.', 'ESTIMATE'],
#  ['Agent[02] must be the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[02] must be the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[02] must be the POSSESSED.', 'ESTIMATE'],
#  ['Agent[03] must be the VILLAGER.', 'ESTIMATE'],
#  ['Agent[03] must be the SEER.', 'ESTIMATE'],
#  ['Agent[03] must be the MEDIUM.', 'ESTIMATE'],
#  ['Agent[03] must be the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[03] must be the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[03] must be the POSSESSED.', 'ESTIMATE'],
#  ['Agent[04] must be the VILLAGER.', 'ESTIMATE'],
#  ['Agent[04] must be the SEER.', 'ESTIMATE'],
#  ['Agent[04] must be the MEDIUM.', 'ESTIMATE'],
#  ['Agent[04] must be the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[04] must be the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[04] must be the POSSESSED.', 'ESTIMATE'],
#  ['Agent[00] seems like the VILLAGER.', 'ESTIMATE'],
#  ['Agent[00] seems like the SEER.', 'ESTIMATE'],
#  ['Agent[00] seems like the MEDIUM.', 'ESTIMATE'],
#  ['Agent[00] seems like the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[00] seems like the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[00] seems like the POSSESSED.', 'ESTIMATE'],
#  ['Agent[01] seems like the VILLAGER.', 'ESTIMATE'],
#  ['Agent[01] seems like the SEER.', 'ESTIMATE'],
#  ['Agent[01] seems like the MEDIUM.', 'ESTIMATE'],
#  ['Agent[01] seems like the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[01] seems like the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[01] seems like the POSSESSED.', 'ESTIMATE'],
#  ['Agent[02] seems like the VILLAGER.', 'ESTIMATE'],
#  ['Agent[02] seems like the SEER.', 'ESTIMATE'],
#  ['Agent[02] seems like the MEDIUM.', 'ESTIMATE'],
#  ['Agent[02] seems like the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[02] seems like the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[02] seems like the POSSESSED.', 'ESTIMATE'],
#  ['Agent[03] seems like the VILLAGER.', 'ESTIMATE'],
#  ['Agent[03] seems like the SEER.', 'ESTIMATE'],
#  ['Agent[03] seems like the MEDIUM.', 'ESTIMATE'],
#  ['Agent[03] seems like the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[03] seems like the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[03] seems like the POSSESSED.', 'ESTIMATE'],
#  ['Agent[04] seems like the VILLAGER.', 'ESTIMATE'],
#  ['Agent[04] seems like the SEER.', 'ESTIMATE'],
#  ['Agent[04] seems like the MEDIUM.', 'ESTIMATE'],
#  ['Agent[04] seems like the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[04] seems like the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[04] seems like the POSSESSED.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the VILLAGER.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the SEER.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the MEDIUM.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the BODYGUARD.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the WEREWOLF.', 'ESTIMATE'],
#  ['I suspect Agent[00] is the POSSESSED.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the VILLAGER.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the SEER.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the MEDIUM.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the BODYGUARD.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the WEREWOLF.', 'ESTIMATE'],
#  ['I suspect Agent[01] is the POSSESSED.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the VILLAGER.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the SEER.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the MEDIUM.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the BODYGUARD.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the WEREWOLF.', 'ESTIMATE'],
#  ['I suspect Agent[02] is the POSSESSED.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the VILLAGER.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the SEER.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the MEDIUM.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the BODYGUARD.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the WEREWOLF.', 'ESTIMATE'],
#  ['I suspect Agent[03] is the POSSESSED.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the VILLAGER.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the SEER.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the MEDIUM.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the BODYGUARD.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the WEREWOLF.', 'ESTIMATE'],
#  ['I suspect Agent[04] is the POSSESSED.', 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the SEER.", 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm convinced Agent[00] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the SEER.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm convinced Agent[01] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the SEER.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm convinced Agent[02] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the SEER.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm convinced Agent[03] is the POSSESSED.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the VILLAGER.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the SEER.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the MEDIUM.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the BODYGUARD.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the WEREWOLF.", 'ESTIMATE'],
#  ["I'm convinced Agent[04] is the POSSESSED.", 'ESTIMATE'],
#  ['I believe Agent[00] is the VILLAGER.', 'ESTIMATE'],
#  ['I believe Agent[00] is the SEER.', 'ESTIMATE'],
#  ['I believe Agent[00] is the MEDIUM.', 'ESTIMATE'],
#  ['I believe Agent[00] is the BODYGUARD.', 'ESTIMATE'],
#  ['I believe Agent[00] is the WEREWOLF.', 'ESTIMATE'],
#  ['I believe Agent[00] is the POSSESSED.', 'ESTIMATE'],
#  ['I believe Agent[01] is the VILLAGER.', 'ESTIMATE'],
#  ['I believe Agent[01] is the SEER.', 'ESTIMATE'],
#  ['I believe Agent[01] is the MEDIUM.', 'ESTIMATE'],
#  ['I believe Agent[01] is the BODYGUARD.', 'ESTIMATE'],
#  ['I believe Agent[01] is the WEREWOLF.', 'ESTIMATE'],
#  ['I believe Agent[01] is the POSSESSED.', 'ESTIMATE'],
#  ['I believe Agent[02] is the VILLAGER.', 'ESTIMATE'],
#  ['I believe Agent[02] is the SEER.', 'ESTIMATE'],
#  ['I believe Agent[02] is the MEDIUM.', 'ESTIMATE'],
#  ['I believe Agent[02] is the BODYGUARD.', 'ESTIMATE'],
#  ['I believe Agent[02] is the WEREWOLF.', 'ESTIMATE'],
#  ['I believe Agent[02] is the POSSESSED.', 'ESTIMATE'],
#  ['I believe Agent[03] is the VILLAGER.', 'ESTIMATE'],
#  ['I believe Agent[03] is the SEER.', 'ESTIMATE'],
#  ['I believe Agent[03] is the MEDIUM.', 'ESTIMATE'],
#  ['I believe Agent[03] is the BODYGUARD.', 'ESTIMATE'],
#  ['I believe Agent[03] is the WEREWOLF.', 'ESTIMATE'],
#  ['I believe Agent[03] is the POSSESSED.', 'ESTIMATE'],
#  ['I believe Agent[04] is the VILLAGER.', 'ESTIMATE'],
#  ['I believe Agent[04] is the SEER.', 'ESTIMATE'],
#  ['I believe Agent[04] is the MEDIUM.', 'ESTIMATE'],
#  ['I believe Agent[04] is the BODYGUARD.', 'ESTIMATE'],
#  ['I believe Agent[04] is the WEREWOLF.', 'ESTIMATE'],
#  ['I believe Agent[04] is the POSSESSED.', 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the VILLAGER.", 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the SEER.", 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the MEDIUM.", 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the BODYGUARD.", 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the WEREWOLF.", 'ESTIMATE'],
#  ["Agent[00]'s behavior looks like the POSSESSED.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the VILLAGER.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the SEER.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the MEDIUM.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the BODYGUARD.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the WEREWOLF.", 'ESTIMATE'],
#  ["Agent[01]'s behavior looks like the POSSESSED.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the VILLAGER.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the SEER.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the MEDIUM.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the BODYGUARD.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the WEREWOLF.", 'ESTIMATE'],
#  ["Agent[02]'s behavior looks like the POSSESSED.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the VILLAGER.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the SEER.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the MEDIUM.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the BODYGUARD.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the WEREWOLF.", 'ESTIMATE'],
#  ["Agent[03]'s behavior looks like the POSSESSED.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the VILLAGER.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the SEER.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the MEDIUM.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the BODYGUARD.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the WEREWOLF.", 'ESTIMATE'],
#  ["Agent[04]'s behavior looks like the POSSESSED.", 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the VILLAGER.', 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the SEER.', 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the MEDIUM.', 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the BODYGUARD.', 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the WEREWOLF.', 'ESTIMATE'],
#  ['Anya, I think Agent[00] is the POSSESSED.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the VILLAGER.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the SEER.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the MEDIUM.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the BODYGUARD.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the WEREWOLF.', 'ESTIMATE'],
#  ['Anya, I think Agent[01] is the POSSESSED.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the VILLAGER.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the SEER.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the MEDIUM.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the BODYGUARD.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the WEREWOLF.', 'ESTIMATE'],
#  ['Anya, I think Agent[02] is the POSSESSED.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the VILLAGER.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the SEER.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the MEDIUM.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the BODYGUARD.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the WEREWOLF.', 'ESTIMATE'],
#  ['Anya, I think Agent[03] is the POSSESSED.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the VILLAGER.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the SEER.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the MEDIUM.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the BODYGUARD.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the WEREWOLF.', 'ESTIMATE'],
#  ['Anya, I think Agent[04] is the POSSESSED.', 'ESTIMATE'],
#  ['Agent[00] is definitely the VILLAGER.', 'ESTIMATE'],
#  ['Agent[00] is definitely the SEER.', 'ESTIMATE'],
#  ['Agent[00] is definitely the MEDIUM.', 'ESTIMATE'],
#  ['Agent[00] is definitely the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[00] is definitely the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[00] is definitely the POSSESSED.', 'ESTIMATE'],
#  ['Agent[01] is definitely the VILLAGER.', 'ESTIMATE'],
#  ['Agent[01] is definitely the SEER.', 'ESTIMATE'],
#  ['Agent[01] is definitely the MEDIUM.', 'ESTIMATE'],
#  ['Agent[01] is definitely the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[01] is definitely the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[01] is definitely the POSSESSED.', 'ESTIMATE'],
#  ['Agent[02] is definitely the VILLAGER.', 'ESTIMATE'],
#  ['Agent[02] is definitely the SEER.', 'ESTIMATE'],
#  ['Agent[02] is definitely the MEDIUM.', 'ESTIMATE'],
#  ['Agent[02] is definitely the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[02] is definitely the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[02] is definitely the POSSESSED.', 'ESTIMATE'],
#  ['Agent[03] is definitely the VILLAGER.', 'ESTIMATE'],
#  ['Agent[03] is definitely the SEER.', 'ESTIMATE'],
#  ['Agent[03] is definitely the MEDIUM.', 'ESTIMATE'],
#  ['Agent[03] is definitely the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[03] is definitely the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[03] is definitely the POSSESSED.', 'ESTIMATE'],
#  ['Agent[04] is definitely the VILLAGER.', 'ESTIMATE'],
#  ['Agent[04] is definitely the SEER.', 'ESTIMATE'],
#  ['Agent[04] is definitely the MEDIUM.', 'ESTIMATE'],
#  ['Agent[04] is definitely the BODYGUARD.', 'ESTIMATE'],
#  ['Agent[04] is definitely the WEREWOLF.', 'ESTIMATE'],
#  ['Agent[04] is definitely the POSSESSED.', 'ESTIMATE'],
#  ['I guess Agent[00] is the VILLAGER.', 'ESTIMATE'],
#  ['I guess Agent[00] is the SEER.', 'ESTIMATE'],
#  ['I guess Agent[00] is the MEDIUM.', 'ESTIMATE'],
#  ['I guess Agent[00] is the BODYGUARD.', 'ESTIMATE'],
#  ['I guess Agent[00] is the WEREWOLF.', 'ESTIMATE'],
#  ['I guess Agent[00] is the POSSESSED.', 'ESTIMATE'],
#  ['I guess Agent[01] is the VILLAGER.', 'ESTIMATE'],
#  ['I guess Agent[01] is the SEER.', 'ESTIMATE'],
#  ['I guess Agent[01] is the MEDIUM.', 'ESTIMATE'],
#  ['I guess Agent[01] is the BODYGUARD.', 'ESTIMATE'],
#  ['I guess Agent[01] is the WEREWOLF.', 'ESTIMATE'],
#  ['I guess Agent[01] is the POSSESSED.', 'ESTIMATE'],
#  ['I guess Agent[02] is the VILLAGER.', 'ESTIMATE'],
#  ['I guess Agent[02] is the SEER.', 'ESTIMATE'],
#  ['I guess Agent[02] is the MEDIUM.', 'ESTIMATE'],
#  ['I guess Agent[02] is the BODYGUARD.', 'ESTIMATE'],
#  ['I guess Agent[02] is the WEREWOLF.', 'ESTIMATE'],
#  ['I guess Agent[02] is the POSSESSED.', 'ESTIMATE'],
#  ['I guess Agent[03] is the VILLAGER.', 'ESTIMATE'],
#  ['I guess Agent[03] is the SEER.', 'ESTIMATE'],
#  ['I guess Agent[03] is the MEDIUM.', 'ESTIMATE'],
#  ['I guess Agent[03] is the BODYGUARD.', 'ESTIMATE'],
#  ['I guess Agent[03] is the WEREWOLF.', 'ESTIMATE'],
#  ['I guess Agent[03] is the POSSESSED.', 'ESTIMATE'],
#  ['I guess Agent[04] is the VILLAGER.', 'ESTIMATE'],
#  ['I guess Agent[04] is the SEER.', 'ESTIMATE'],
#  ['I guess Agent[04] is the MEDIUM.', 'ESTIMATE'],
#  ['I guess Agent[04] is the BODYGUARD.', 'ESTIMATE'],
#  ['I guess Agent[04] is the WEREWOLF.', 'ESTIMATE'],
#  ['I guess Agent[04] is the POSSESSED.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a VILLAGER.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a SEER.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a MEDIUM.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a BODYGUARD.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a WEREWOLF.', 'ESTIMATE'],
#  ['Possibly  Agent[00] is a POSSESSED.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a VILLAGER.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a SEER.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a MEDIUM.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a BODYGUARD.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a WEREWOLF.', 'ESTIMATE'],
#  ['Possibly  Agent[01] is a POSSESSED.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a VILLAGER.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a SEER.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a MEDIUM.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a BODYGUARD.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a WEREWOLF.', 'ESTIMATE'],
#  ['Possibly  Agent[02] is a POSSESSED.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a VILLAGER.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a SEER.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a MEDIUM.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a BODYGUARD.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a WEREWOLF.', 'ESTIMATE'],
#  ['Possibly  Agent[03] is a POSSESSED.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a VILLAGER.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a SEER.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a MEDIUM.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a BODYGUARD.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a WEREWOLF.', 'ESTIMATE'],
#  ['Possibly  Agent[04] is a POSSESSED.', 'ESTIMATE'],
#  ['My role is the VILLAGER.', 'CO'],
#  ['My role is the SEER.', 'CO'],
#  ['My role is the MEDIUM.', 'CO'],
#  ['My role is the BODYGUARD.', 'CO'],
#  ['My role is the WEREWOLF.', 'CO'],
#  ['My role is the POSSESSED.', 'CO'],
#  ["Actually, I'm the VILLAGER.", 'CO'],
#  ["Actually, I'm the SEER.", 'CO'],
#  ["Actually, I'm the MEDIUM.", 'CO'],
#  ["Actually, I'm the BODYGUARD.", 'CO'],
#  ["Actually, I'm the WEREWOLF.", 'CO'],
#  ["Actually, I'm the POSSESSED.", 'CO'],
#  ["I'm assigned the role of the VILLAGER.", 'CO'],
#  ["I'm assigned the role of the SEER.", 'CO'],
#  ["I'm assigned the role of the MEDIUM.", 'CO'],
#  ["I'm assigned the role of the BODYGUARD.", 'CO'],
#  ["I'm assigned the role of the WEREWOLF.", 'CO'],
#  ["I'm assigned the role of the POSSESSED.", 'CO'],
#  ["I'm the VILLAGER in this game.", 'CO'],
#  ["I'm the SEER in this game.", 'CO'],
#  ["I'm the MEDIUM in this game.", 'CO'],
#  ["I'm the BODYGUARD in this game.", 'CO'],
#  ["I'm the WEREWOLF in this game.", 'CO'],
#  ["I'm the POSSESSED in this game.", 'CO'],
#  ["I'm actually the VILLAGER.", 'CO'],
#  ["I'm actually the SEER.", 'CO'],
#  ["I'm actually the MEDIUM.", 'CO'],
#  ["I'm actually the BODYGUARD.", 'CO'],
#  ["I'm actually the WEREWOLF.", 'CO'],
#  ["I'm actually the POSSESSED.", 'CO'],
#  ['I was given the position of VILLAGER.', 'CO'],
#  ['I was given the position of SEER.', 'CO'],
#  ['I was given the position of MEDIUM.', 'CO'],
#  ['I was given the position of BODYGUARD.', 'CO'],
#  ['I was given the position of WEREWOLF.', 'CO'],
#  ['I was given the position of POSSESSED.', 'CO'],
#  ["I'm a normal VILLAGER.", 'CO'],
#  ["I'm a normal SEER.", 'CO'],
#  ["I'm a normal MEDIUM.", 'CO'],
#  ["I'm a normal BODYGUARD.", 'CO'],
#  ["I'm a normal WEREWOLF.", 'CO'],
#  ["I'm a normal POSSESSED.", 'CO'],
#  ['I have gained the ability of VILLAGER.', 'CO'],
#  ['I have gained the ability of SEER.', 'CO'],
#  ['I have gained the ability of MEDIUM.', 'CO'],
#  ['I have gained the ability of BODYGUARD.', 'CO'],
#  ['I have gained the ability of WEREWOLF.', 'CO'],
#  ['I have gained the ability of POSSESSED.', 'CO'],
#  ['I am just a VILLAGER.', 'CO'],
#  ['I am just a SEER.', 'CO'],
#  ['I am just a MEDIUM.', 'CO'],
#  ['I am just a BODYGUARD.', 'CO'],
#  ['I am just a WEREWOLF.', 'CO'],
#  ['I am just a POSSESSED.', 'CO'],
#  ['To tell you the truth, I am the VILLAGER.', 'CO'],
#  ['To tell you the truth, I am the SEER.', 'CO'],
#  ['To tell you the truth, I am the MEDIUM.', 'CO'],
#  ['To tell you the truth, I am the BODYGUARD.', 'CO'],
#  ['To tell you the truth, I am the WEREWOLF.', 'CO'],
#  ['To tell you the truth, I am the POSSESSED.', 'CO'],
#  ['Agent[00] is acting really shady.', 'SUSPECT'],
#  ['Agent[01] is acting really shady.', 'SUSPECT'],
#  ['Agent[02] is acting really shady.', 'SUSPECT'],
#  ['Agent[03] is acting really shady.', 'SUSPECT'],
#  ['Agent[04] is acting really shady.', 'SUSPECT'],
#  ['Agent[00] has been behaving quite strangely.', 'SUSPECT'],
#  ['Agent[01] has been behaving quite strangely.', 'SUSPECT'],
#  ['Agent[02] has been behaving quite strangely.', 'SUSPECT'],
#  ['Agent[03] has been behaving quite strangely.', 'SUSPECT'],
#  ['Agent[04] has been behaving quite strangely.', 'SUSPECT'],
#  ["There's something off about the way Agent[00] is acting.", 'SUSPECT'],
#  ["There's something off about the way Agent[01] is acting.", 'SUSPECT'],
#  ["There's something off about the way Agent[02] is acting.", 'SUSPECT'],
#  ["There's something off about the way Agent[03] is acting.", 'SUSPECT'],
#  ["There's something off about the way Agent[04] is acting.", 'SUSPECT'],
#  ["I can't help but feel there's something fishy about Agent[00].", 'SUSPECT'],
#  ["I can't help but feel there's something fishy about Agent[01].", 'SUSPECT'],
#  ["I can't help but feel there's something fishy about Agent[02].", 'SUSPECT'],
#  ["I can't help but feel there's something fishy about Agent[03].", 'SUSPECT'],
#  ["I can't help but feel there's something fishy about Agent[04].", 'SUSPECT'],
#  ["Agent[00]'s behavior is definitely out of the ordinary.", 'SUSPECT'],
#  ["Agent[01]'s behavior is definitely out of the ordinary.", 'SUSPECT'],
#  ["Agent[02]'s behavior is definitely out of the ordinary.", 'SUSPECT'],
#  ["Agent[03]'s behavior is definitely out of the ordinary.", 'SUSPECT'],
#  ["Agent[04]'s behavior is definitely out of the ordinary.", 'SUSPECT'],
#  ["Agent[00]'s recent behavior is highly questionable.", 'SUSPECT'],
#  ["Agent[01]'s recent behavior is highly questionable.", 'SUSPECT'],
#  ["Agent[02]'s recent behavior is highly questionable.", 'SUSPECT'],
#  ["Agent[03]'s recent behavior is highly questionable.", 'SUSPECT'],
#  ["Agent[04]'s recent behavior is highly questionable.", 'SUSPECT'],
#  ['Agent[00] cannot be trusted.', 'SUSPECT'],
#  ['Agent[01] cannot be trusted.', 'SUSPECT'],
#  ['Agent[02] cannot be trusted.', 'SUSPECT'],
#  ['Agent[03] cannot be trusted.', 'SUSPECT'],
#  ['Agent[04] cannot be trusted.', 'SUSPECT'],
#  ['What Agent[00] said is suspicious.', 'SUSPECT'],
#  ['What Agent[01] said is suspicious.', 'SUSPECT'],
#  ['What Agent[02] said is suspicious.', 'SUSPECT'],
#  ['What Agent[03] said is suspicious.', 'SUSPECT'],
#  ['What Agent[04] said is suspicious.', 'SUSPECT'],
#  ['Is Agent[00] really trustworthy?', 'SUSPECT'],
#  ['Is Agent[01] really trustworthy?', 'SUSPECT'],
#  ['Is Agent[02] really trustworthy?', 'SUSPECT'],
#  ['Is Agent[03] really trustworthy?', 'SUSPECT'],
#  ['Is Agent[04] really trustworthy?', 'SUSPECT'],
#  ["Agent[00]'s opinion is dubious.", 'SUSPECT'],
#  ["Agent[01]'s opinion is dubious.", 'SUSPECT'],
#  ["Agent[02]'s opinion is dubious.", 'SUSPECT'],
#  ["Agent[03]'s opinion is dubious.", 'SUSPECT'],
#  ["Agent[04]'s opinion is dubious.", 'SUSPECT'],
#  ['I guess the questionable one is Agent[00].', 'SUSPECT'],
#  ['I guess the questionable one is Agent[01].', 'SUSPECT'],
#  ['I guess the questionable one is Agent[02].', 'SUSPECT'],
#  ['I guess the questionable one is Agent[03].', 'SUSPECT'],
#  ['I guess the questionable one is Agent[04].', 'SUSPECT'],
#  ['I choose Agent[00] for my vote.', 'VOTE'],
#  ['I choose Agent[01] for my vote.', 'VOTE'],
#  ['I choose Agent[02] for my vote.', 'VOTE'],
#  ['I choose Agent[03] for my vote.', 'VOTE'],
#  ['I choose Agent[04] for my vote.', 'VOTE'],
#  ['Agent[00] gets my vote.', 'VOTE'],
#  ['Agent[01] gets my vote.', 'VOTE'],
#  ['Agent[02] gets my vote.', 'VOTE'],
#  ['Agent[03] gets my vote.', 'VOTE'],
#  ['Agent[04] gets my vote.', 'VOTE'],
#  ['My vote goes to Agent[00].', 'VOTE'],
#  ['My vote goes to Agent[01].', 'VOTE'],
#  ['My vote goes to Agent[02].', 'VOTE'],
#  ['My vote goes to Agent[03].', 'VOTE'],
#  ['My vote goes to Agent[04].', 'VOTE'],
#  ['I believe Agent[00] should be voted out.', 'VOTE'],
#  ['I believe Agent[01] should be voted out.', 'VOTE'],
#  ['I believe Agent[02] should be voted out.', 'VOTE'],
#  ['I believe Agent[03] should be voted out.', 'VOTE'],
#  ['I believe Agent[04] should be voted out.', 'VOTE'],
#  ['My choice is Agent[00].', 'VOTE'],
#  ['My choice is Agent[01].', 'VOTE'],
#  ['My choice is Agent[02].', 'VOTE'],
#  ['My choice is Agent[03].', 'VOTE'],
#  ['My choice is Agent[04].', 'VOTE'],
#  ['I will vote Agent[00].', 'VOTE'],
#  ['I will vote Agent[01].', 'VOTE'],
#  ['I will vote Agent[02].', 'VOTE'],
#  ['I will vote Agent[03].', 'VOTE'],
#  ['I will vote Agent[04].', 'VOTE'],
#  ['I want to vote Agent[00].', 'VOTE'],
#  ['I want to vote Agent[01].', 'VOTE'],
#  ['I want to vote Agent[02].', 'VOTE'],
#  ['I want to vote Agent[03].', 'VOTE'],
#  ['I want to vote Agent[04].', 'VOTE'],
#  ['Agent[00] should be exiled.', 'VOTE'],
#  ['Agent[01] should be exiled.', 'VOTE'],
#  ['Agent[02] should be exiled.', 'VOTE'],
#  ['Agent[03] should be exiled.', 'VOTE'],
#  ['Agent[04] should be exiled.', 'VOTE'],
#  ['I would put in Agent[00].', 'VOTE'],
#  ['I would put in Agent[01].', 'VOTE'],
#  ['I would put in Agent[02].', 'VOTE'],
#  ['I would put in Agent[03].', 'VOTE'],
#  ['I would put in Agent[04].', 'VOTE'],
#  ['I would vote Agent[00].', 'VOTE'],
#  ['I would vote Agent[01].', 'VOTE'],
#  ['I would vote Agent[02].', 'VOTE'],
#  ['I would vote Agent[03].', 'VOTE'],
#  ['I would vote Agent[04].', 'VOTE'],
#  ['Planning to vote for Agent[00].', 'VOTE'],
#  ['Planning to vote for Agent[01].', 'VOTE'],
#  ['Planning to vote for Agent[02].', 'VOTE'],
#  ['Planning to vote for Agent[03].', 'VOTE'],
#  ['Planning to vote for Agent[04].', 'VOTE'],
#  ['I would like to investigate Agent[00].', 'DIVINATION'],
#  ['I would like to investigate Agent[01].', 'DIVINATION'],
#  ['I would like to investigate Agent[02].', 'DIVINATION'],
#  ['I would like to investigate Agent[03].', 'DIVINATION'],
#  ['I would like to investigate Agent[04].', 'DIVINATION'],
#  ['My next target for divination is Agent[00].', 'DIVINATION'],
#  ['My next target for divination is Agent[01].', 'DIVINATION'],
#  ['My next target for divination is Agent[02].', 'DIVINATION'],
#  ['My next target for divination is Agent[03].', 'DIVINATION'],
#  ['My next target for divination is Agent[04].', 'DIVINATION'],
#  ['Agent[00] is my choice for divination.', 'DIVINATION'],
#  ['Agent[01] is my choice for divination.', 'DIVINATION'],
#  ['Agent[02] is my choice for divination.', 'DIVINATION'],
#  ['Agent[03] is my choice for divination.', 'DIVINATION'],
#  ['Agent[04] is my choice for divination.', 'DIVINATION'],
#  ['I intend to divine Agent[00].', 'DIVINATION'],
#  ['I intend to divine Agent[01].', 'DIVINATION'],
#  ['I intend to divine Agent[02].', 'DIVINATION'],
#  ['I intend to divine Agent[03].', 'DIVINATION'],
#  ['I intend to divine Agent[04].', 'DIVINATION'],
#  ["I'm going to focus my divination on Agent[00].", 'DIVINATION'],
#  ["I'm going to focus my divination on Agent[01].", 'DIVINATION'],
#  ["I'm going to focus my divination on Agent[02].", 'DIVINATION'],
#  ["I'm going to focus my divination on Agent[03].", 'DIVINATION'],
#  ["I'm going to focus my divination on Agent[04].", 'DIVINATION'],
#  ["I'm going to divine Agent[00] tonight.", 'DIVINATION'],
#  ["I'm going to divine Agent[01] tonight.", 'DIVINATION'],
#  ["I'm going to divine Agent[02] tonight.", 'DIVINATION'],
#  ["I'm going to divine Agent[03] tonight.", 'DIVINATION'],
#  ["I'm going to divine Agent[04] tonight.", 'DIVINATION'],
#  ['I will divine Agent[00] next.', 'DIVINATION'],
#  ['I will divine Agent[01] next.', 'DIVINATION'],
#  ['I will divine Agent[02] next.', 'DIVINATION'],
#  ['I will divine Agent[03] next.', 'DIVINATION'],
#  ['I will divine Agent[04] next.', 'DIVINATION'],
#  ["I can tell the Agent[00]'s role tomorrow.", 'DIVINATION'],
#  ["I can tell the Agent[01]'s role tomorrow.", 'DIVINATION'],
#  ["I can tell the Agent[02]'s role tomorrow.", 'DIVINATION'],
#  ["I can tell the Agent[03]'s role tomorrow.", 'DIVINATION'],
#  ["I can tell the Agent[04]'s role tomorrow.", 'DIVINATION'],
#  ["I will unmask Agent[00]'s true nature.", 'DIVINATION'],
#  ["I will unmask Agent[01]'s true nature.", 'DIVINATION'],
#  ["I will unmask Agent[02]'s true nature.", 'DIVINATION'],
#  ["I will unmask Agent[03]'s true nature.", 'DIVINATION'],
#  ["I will unmask Agent[04]'s true nature.", 'DIVINATION'],
#  ['I might investigate Agent[00] next.', 'DIVINATION'],
#  ['I might investigate Agent[01] next.', 'DIVINATION'],
#  ['I might investigate Agent[02] next.', 'DIVINATION'],
#  ['I might investigate Agent[03] next.', 'DIVINATION'],
#  ['I might investigate Agent[04] next.', 'DIVINATION'],
#  ['I investigated Agent[00] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[00] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[01] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[01] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[02] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[02] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[03] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[03] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[04] and discovered he is a [TEAM].', 'DIVINED'],
#  ['I investigated Agent[04] and discovered he is a [TEAM].', 'DIVINED'],
#  ['When I looked into Agent[00], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[00], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[01], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[01], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[02], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[02], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[03], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[03], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[04], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['When I looked into Agent[04], it was revealed that he is [TEAM].',
#   'DIVINED'],
#  ['My divination revealed that Agent[00] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[00] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[01] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[01] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[02] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[02] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[03] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[03] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[04] is a [TEAM].', 'DIVINED'],
#  ['My divination revealed that Agent[04] is a [TEAM].', 'DIVINED'],
#  ['After performing a divination on Agent[00], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[00], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[01], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[01], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[02], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[02], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[03], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[03], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[04], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['After performing a divination on Agent[04], it was clear that he is [TEAM].',
#   'DIVINED'],
#  ['I divined Agent[00] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[00] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[01] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[01] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[02] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[02] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[03] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[03] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[04] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['I divined Agent[04] and the results showed he is a [TEAM].', 'DIVINED'],
#  ['Anya divined Agent[00], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[00], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[01], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[01], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[02], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[02], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[03], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[03], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[04], and he was the [TEAM]!', 'DIVINED'],
#  ['Anya divined Agent[04], and he was the [TEAM]!', 'DIVINED'],
#  ['I divined Agent[00]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[00]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[01]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[01]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[02]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[02]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[03]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[03]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[04]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['I divined Agent[04]. What he said was true, he is the [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[00] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[00] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[01] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[01] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[02] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[02] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[03] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[03] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[04] is [TEAM].', 'DIVINED'],
#  ['According to my ability, Agent[04] is [TEAM].', 'DIVINED'],
#  ['The God says Agent[00] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[00] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[01] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[01] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[02] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[02] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[03] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[03] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[04] is the [TEAM].', 'DIVINED'],
#  ['The God says Agent[04] is the [TEAM].', 'DIVINED'],
#  ["I revealed Agent[00]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[00]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[01]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[01]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[02]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[02]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[03]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[03]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[04]'s true nature is [TEAM].", 'DIVINED'],
#  ["I revealed Agent[04]'s true nature is [TEAM].", 'DIVINED'],
#  ['I’m on the same page as Agent[00].', 'AGREE'],
#  ['I’m on the same page as Agent[01].', 'AGREE'],
#  ['I’m on the same page as Agent[02].', 'AGREE'],
#  ['I’m on the same page as Agent[03].', 'AGREE'],
#  ['I’m on the same page as Agent[04].', 'AGREE'],
#  ['I’m in agreement with Agent[00].', 'AGREE'],
#  ['I’m in agreement with Agent[01].', 'AGREE'],
#  ['I’m in agreement with Agent[02].', 'AGREE'],
#  ['I’m in agreement with Agent[03].', 'AGREE'],
#  ['I’m in agreement with Agent[04].', 'AGREE'],
#  ["I support Agent[00]'s viewpoint.", 'AGREE'],
#  ["I support Agent[01]'s viewpoint.", 'AGREE'],
#  ["I support Agent[02]'s viewpoint.", 'AGREE'],
#  ["I support Agent[03]'s viewpoint.", 'AGREE'],
#  ["I support Agent[04]'s viewpoint.", 'AGREE'],
#  ["I back Agent[00]'s opinion.", 'AGREE'],
#  ["I back Agent[01]'s opinion.", 'AGREE'],
#  ["I back Agent[02]'s opinion.", 'AGREE'],
#  ["I back Agent[03]'s opinion.", 'AGREE'],
#  ["I back Agent[04]'s opinion.", 'AGREE'],
#  ["I align with Agent[00]'s perspective.", 'AGREE'],
#  ["I align with Agent[01]'s perspective.", 'AGREE'],
#  ["I align with Agent[02]'s perspective.", 'AGREE'],
#  ["I align with Agent[03]'s perspective.", 'AGREE'],
#  ["I align with Agent[04]'s perspective.", 'AGREE'],
#  ["Agree with Agent[00]'s opinion.", 'AGREE'],
#  ["Agree with Agent[01]'s opinion.", 'AGREE'],
#  ["Agree with Agent[02]'s opinion.", 'AGREE'],
#  ["Agree with Agent[03]'s opinion.", 'AGREE'],
#  ["Agree with Agent[04]'s opinion.", 'AGREE'],
#  ["I strongly agree with the Agent[00]'s suggestion.", 'AGREE'],
#  ["I strongly agree with the Agent[01]'s suggestion.", 'AGREE'],
#  ["I strongly agree with the Agent[02]'s suggestion.", 'AGREE'],
#  ["I strongly agree with the Agent[03]'s suggestion.", 'AGREE'],
#  ["I strongly agree with the Agent[04]'s suggestion.", 'AGREE'],
#  ['I think Agent[00] is not the VILLAGER', 'NOT ESTIMATE'],
#  ['I think Agent[00] is not the SEER', 'NOT ESTIMATE'],
#  ['I think Agent[00] is not the MEDIUM', 'NOT ESTIMATE'],
#  ['I think Agent[00] is not the BODYGUARD', 'NOT ESTIMATE'],
#  ['I think Agent[00] is not the WEREWOLF', 'NOT ESTIMATE'],
#  ['I think Agent[00] is not the POSSESSED', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the VILLAGER', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the SEER', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the MEDIUM', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the BODYGUARD', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the WEREWOLF', 'NOT ESTIMATE'],
#  ['I think Agent[01] is not the POSSESSED', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the VILLAGER', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the SEER', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the MEDIUM', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the BODYGUARD', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the WEREWOLF', 'NOT ESTIMATE'],
#  ['I think Agent[02] is not the POSSESSED', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the VILLAGER', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the SEER', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the MEDIUM', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the BODYGUARD', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the WEREWOLF', 'NOT ESTIMATE'],
#  ['I think Agent[03] is not the POSSESSED', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the VILLAGER', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the SEER', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the MEDIUM', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the BODYGUARD', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the WEREWOLF', 'NOT ESTIMATE'],
#  ['I think Agent[04] is not the POSSESSED', 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[00] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[01] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[02] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[03] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm pretty sure Agent[04] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ['Agent[00] must not be the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[00] must not be the SEER.', 'NOT ESTIMATE'],
#  ['Agent[00] must not be the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[00] must not be the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[00] must not be the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[00] must not be the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the SEER.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[01] must not be the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the SEER.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[02] must not be the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the SEER.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[03] must not be the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the SEER.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[04] must not be the POSSESSED.', 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[00] doesn't seem like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[01] doesn't seem like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[02] doesn't seem like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[03] doesn't seem like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[04] doesn't seem like the POSSESSED.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I suspect Agent[00] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I suspect Agent[01] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I suspect Agent[02] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I suspect Agent[03] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the VILLAGER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the SEER.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the MEDIUM.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I suspect Agent[04] isn't the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the SEER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[00] is not the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the SEER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[01] is not the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the SEER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[02] is not the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the SEER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[03] is not the POSSESSED.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the VILLAGER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the SEER.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the MEDIUM.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I'm convinced Agent[04] is not the POSSESSED.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the VILLAGER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the SEER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the MEDIUM.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[00] is the POSSESSED.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the VILLAGER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the SEER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the MEDIUM.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[01] is the POSSESSED.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the VILLAGER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the SEER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the MEDIUM.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[02] is the POSSESSED.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the VILLAGER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the SEER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the MEDIUM.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[03] is the POSSESSED.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the VILLAGER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the SEER.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the MEDIUM.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the BODYGUARD.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the WEREWOLF.", 'NOT ESTIMATE'],
#  ["I don't believe Agent[04] is the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[00]'s behavior doesn't looks like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[01]'s behavior doesn't looks like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[02]'s behavior doesn't looks like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[03]'s behavior doesn't looks like the POSSESSED.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the VILLAGER.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the SEER.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the MEDIUM.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the BODYGUARD.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the WEREWOLF.", 'NOT ESTIMATE'],
#  ["Agent[04]'s behavior doesn't looks like the POSSESSED.", 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the VILLAGER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the SEER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the MEDIUM.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[00] is not the POSSESSED.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the VILLAGER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the SEER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the MEDIUM.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[01] is not the POSSESSED.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the VILLAGER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the SEER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the MEDIUM.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[02] is not the POSSESSED.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the VILLAGER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the SEER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the MEDIUM.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[03] is not the POSSESSED.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the VILLAGER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the SEER.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the MEDIUM.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Anya, I think Agent[04] is not the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the SEER.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[00] is not definitely the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the SEER.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the MEDIUM.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the BODYGUARD.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the WEREWOLF.', 'NOT ESTIMATE'],
#  ['Agent[01] is not definitely the POSSESSED.', 'NOT ESTIMATE'],
#  ['Agent[02] is not definitely the VILLAGER.', 'NOT ESTIMATE'],
#  ['Agent[02] is not definitely the SEER.', 'NOT ESTIMATE'],
#  ['Agent[02] is not definitely the MEDIUM.', 'NOT ESTIMATE'],
#  ...]

# %%
Df_all = pd.DataFrame(data, columns=["sentence", "verb"])
Df_all
# Out:
#                                          sentence       verb
# 0               I think Agent[00] is the VILLAGER   ESTIMATE
# 1                   I think Agent[00] is the SEER   ESTIMATE
# 2                 I think Agent[00] is the MEDIUM   ESTIMATE
# 3              I think Agent[00] is the BODYGUARD   ESTIMATE
# 4               I think Agent[00] is the WEREWOLF   ESTIMATE
# ...                                           ...        ...
# 1160  I don't align with Agent[00]'s perspective.  NOT AGREE
# 1161  I don't align with Agent[01]'s perspective.  NOT AGREE
# 1162  I don't align with Agent[02]'s perspective.  NOT AGREE
# 1163  I don't align with Agent[03]'s perspective.  NOT AGREE
# 1164  I don't align with Agent[04]'s perspective.  NOT AGREE
#
# [1165 rows x 2 columns]

# %%
from embedding import get_embedding
Df_all["embedded"] = Df_all["sentence"].map(lambda x: get_embedding(x))
Df_all
# Out:
#                                          sentence       verb  \
# 0               I think Agent[00] is the VILLAGER   ESTIMATE
# 1                   I think Agent[00] is the SEER   ESTIMATE
# 2                 I think Agent[00] is the MEDIUM   ESTIMATE
# 3              I think Agent[00] is the BODYGUARD   ESTIMATE
# 4               I think Agent[00] is the WEREWOLF   ESTIMATE
# ...                                           ...        ...
# 1160  I don't align with Agent[00]'s perspective.  NOT AGREE
# 1161  I don't align with Agent[01]'s perspective.  NOT AGREE
# 1162  I don't align with Agent[02]'s perspective.  NOT AGREE
# 1163  I don't align with Agent[03]'s perspective.  NOT AGREE
# 1164  I don't align with Agent[04]'s perspective.  NOT AGREE
#
#                                                embedded
# 0     [-0.03160594776272774, 0.0009460010332986712, ...
# 1     [-0.0273969117552042, -0.011489843018352985, 0...
# 2     [-0.006798113230615854, -0.006818466819822788,...
# 3     [-0.003204112173989415, 0.009231535717844963, ...
# 4     [-0.017370691522955894, 0.002385223750025034, ...
# ...                                                 ...
# 1160  [-0.03167816251516342, 0.023226819932460785, 0...
# 1161  [-0.033647119998931885, 0.022867951542139053, ...
# 1162  [-0.030103590339422226, 0.01959971897304058, 0...
# 1163  [-0.03203131631016731, 0.020662177354097366, 0...
# 1164  [-0.030088258907198906, 0.026264425367116928, ...
#
# [1165 rows x 3 columns]

# %%
Df_all.to_csv("embedded_all.csv")

# %% [markdown]
# ## 一旦2段階embedding方針

# %%
# 一旦、indexを文章にしてdataframeに
ans = []
for column in df.columns:
    for sentence in df[column].dropna().values:
        ans.append([sentence, column])

Df = pd.DataFrame(ans, columns=["sentence", "verb"])
Df
# Out:
#                                       sentence       verb
# 0                I think [AGENT] is the [ROLE]   ESTIMATE
# 1       I'm pretty sure [AGENT] is the [ROLE].   ESTIMATE
# 2                  [AGENT] must be the [ROLE].   ESTIMATE
# 3               [AGENT] seems like the [ROLE].   ESTIMATE
# 4             I suspect [AGENT] is the [ROLE].   ESTIMATE
# ..                                         ...        ...
# 101       I’m not on the same page as [AGENT].  NOT AGREE
# 102         I’m not in agreement with [AGENT].  NOT AGREE
# 103       I don't support [AGENT]'s viewpoint.  NOT AGREE
# 104            I don't back [AGENT]'s opinion.  NOT AGREE
# 105  I don't align with [AGENT]'s perspective.  NOT AGREE
#
# [106 rows x 2 columns]

# %%
from embedding import get_embedding
Df["embedded"] = Df["sentence"].map(lambda x: get_embedding(x))
Df
# Out:
#                                       sentence       verb  \
# 0                I think [AGENT] is the [ROLE]   ESTIMATE
# 1       I'm pretty sure [AGENT] is the [ROLE].   ESTIMATE
# 2                  [AGENT] must be the [ROLE].   ESTIMATE
# 3               [AGENT] seems like the [ROLE].   ESTIMATE
# 4             I suspect [AGENT] is the [ROLE].   ESTIMATE
# ..                                         ...        ...
# 101       I’m not on the same page as [AGENT].  NOT AGREE
# 102         I’m not in agreement with [AGENT].  NOT AGREE
# 103       I don't support [AGENT]'s viewpoint.  NOT AGREE
# 104            I don't back [AGENT]'s opinion.  NOT AGREE
# 105  I don't align with [AGENT]'s perspective.  NOT AGREE
#
#                                               embedded
# 0    [-0.025435129180550575, 0.02359001524746418, -...
# 1    [-0.026439836248755455, 0.015423237346112728, ...
# 2    [-0.03527791053056717, 0.05349048972129822, -0...
# 3    [-0.03959893807768822, 0.03399699181318283, -0...
# 4    [-0.024901622906327248, 0.03169022500514984, -...
# ..                                                 ...
# 101  [-0.02111106365919113, 0.023209236562252045, 0...
# 102  [-0.027951616793870926, 0.04496261104941368, 0...
# 103  [-0.0039258478209376335, 0.013852584175765514,...
# 104  [0.02674938552081585, 0.006069068796932697, -0...
# 105  [-0.02435404062271118, 0.0319083034992218, 0.0...
#
# [106 rows x 3 columns]

# %%
Df
# Out:
#                                       sentence       verb  \
# 0                I think [AGENT] is the [ROLE]   ESTIMATE
# 1       I'm pretty sure [AGENT] is the [ROLE].   ESTIMATE
# 2                  [AGENT] must be the [ROLE].   ESTIMATE
# 3               [AGENT] seems like the [ROLE].   ESTIMATE
# 4             I suspect [AGENT] is the [ROLE].   ESTIMATE
# ..                                         ...        ...
# 101       I’m not on the same page as [AGENT].  NOT AGREE
# 102         I’m not in agreement with [AGENT].  NOT AGREE
# 103       I don't support [AGENT]'s viewpoint.  NOT AGREE
# 104            I don't back [AGENT]'s opinion.  NOT AGREE
# 105  I don't align with [AGENT]'s perspective.  NOT AGREE
#
#                                               embedded
# 0    [-0.025435129180550575, 0.02359001524746418, -...
# 1    [-0.026439836248755455, 0.015423237346112728, ...
# 2    [-0.03527791053056717, 0.05349048972129822, -0...
# 3    [-0.03959893807768822, 0.03399699181318283, -0...
# 4    [-0.024901622906327248, 0.03169022500514984, -...
# ..                                                 ...
# 101  [-0.02111106365919113, 0.023209236562252045, 0...
# 102  [-0.027951616793870926, 0.04496261104941368, 0...
# 103  [-0.0039258478209376335, 0.013852584175765514,...
# 104  [0.02674938552081585, 0.006069068796932697, -0...
# 105  [-0.02435404062271118, 0.0319083034992218, 0.0...
#
# [106 rows x 3 columns]

# %%
Df.to_csv("embedded.csv")

# %%
import breakdown

talker = "Agent[00]"
sentence = "Agent[00]を占ったら黒だったよ。Agent[01]を占ったら白だったよ。"
brokendown = eval(breakdown.get_list(talker, sentence)) # outputがstrなことがあるから
[get_embedding(sentense) for sentense in brokendown]
# Out:
# [array([-0.05419775,  0.01943717, -0.00595273, ..., -0.01346533,
#         -0.01221132,  0.03121264]),
#  array([-0.04749064, -0.01903382, -0.0144632 , ..., -0.02437143,
#         -0.02612455,  0.03160303])]
